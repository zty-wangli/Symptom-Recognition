# %%
import os
import copy
import json
import logging

import torch
from torch.utils.data import TensorDataset


import re
import pandas as pd
from bert4keras.snippets import sequence_padding,DataGenerator
from bert4keras.tokenizers import Tokenizer


entity_labels = ['Symptom','Operation','Medical_Examination','Drug_Category','Drug']

id2label = {i:j for i,j in enumerate(sorted(entity_labels))}
label2id = {j:i for i,j in id2label.items()}

num_labels = len(entity_labels) * 2 + 1

vocab_path = './bert_weight_file/uncased_L-4_H-768_A-12/vocab.txt'
tokenizer = Tokenizer(vocab_path,do_lower_case=True)



def load_data(data_path,max_len):
    
    sentence = []
    labels = []
    X = []
    y = []
    datasets = []
    samples_len = []
    split_pattern = re.compile(r'[;；。，、？\.\?!]')
    with open(data_path,'r',encoding= 'utf8') as f:
        for line in f.readlines():
            line = line.strip().split()
            if(not line or len(line) < 2):
                X.append(sentence.copy())
                y.append(labels.copy())
                sentence.clear()
                labels.clear()
                continue
            word, tag = line[0], line[1]
            if split_pattern.match(word) and len(sentence) >= max_len:
                sentence.append(word)
                labels.append(tag)
                sentence.clear()
                labels.clear()
            else:
                sentence.append(word)
                labels.append(tag)
    if len(sentence):
        X.append(sentence.copy())
        sentence.clear()
        y.append(labels.copy())
        labels.clear()

    for token_seq,label_seq in zip(X,y):
        if len(token_seq) < 2:
            continue
        sample_seq, last_flag = [], ''
        for token, this_flag in zip(token_seq,label_seq):
            
            if this_flag == 'O' and last_flag == 'O':
                sample_seq[-1][0] += token
            elif this_flag == 'O' and last_flag != 'O':
                sample_seq.append([token, 'O'])
            elif this_flag[:1] == 'B':
                sample_seq.append([token, this_flag[2:]]) 
                save = token
            elif this_flag[:1] == 'I' and last_flag[:1] == 'B':
                del sample_seq[-1][-1] 
                del sample_seq[-1][-1] 
                sample_seq.append([save+token, this_flag[2:]])
                save = save+token
            elif this_flag[:1] == 'I' and last_flag[:1] == 'I':
                del sample_seq[-1][-1] 
                del sample_seq[-1][-1]
                sample_seq.append([save+token, this_flag[2:]])
                save = save+token
            last_flag = this_flag
        datasets.append([x for x in sample_seq if x != []])
        
        samples_len.append(len(token_seq))
        

        
    return datasets,y

# %%
if __name__ == '__main__':
    data_path = './ner_data/train/train.txt'
    d = load_data(data_path,128)

# %%
d
# Out:
# ([[['医生：你好我是您的接诊医生', 'O']],
#   [['医生：宝贝最近吃奶量可以吗？下降了吗', 'O']],
#   [['患者：没有，也没怎么', 'O'], ['哭闹', 'Symptom']],
#   [['医生：宝妈有没有吃生冷辛辣刺激食物油腻食物来吗？', 'O']],
#   [['医生：宝贝奶粉的话最近换过牌子吗？', 'O']],
#   [['医生：宝贝肚子着凉来吗？', 'O']],
#   [['患者：喝茶油腻也少，菜吃很多', 'O']],
#   [['医生：嗯嗯，宝妈饮食一定注意，生冷辛辣刺激食物不能吃油腻食物不能吃，特别油腻食物的奥，清淡饮食为主，这个时候宝贝胃肠功能可能会有影响，能吃多少吃多少别强喂的奥！',
#     'O']],
#   [['医生：宝贝最近有没有', 'O'], ['呕吐', 'Symptom'], ['症状呢？', 'O']],
#   [['患者：', 'O'],
#    ['呕吐', 'Symptom'],
#    ['，有时会', 'O'],
#    ['吐', 'Symptom'],
#    ['，不多', 'O']],
#   [['医生：嗯嗯，如果那种漾奶，每次量很少的话就问题不大，这个时候小婴儿胃处于水平位，所以很容易漾奶的奥，看好宝贝别呛到了就可以', 'O']],
#   [['医生：宝贝如果', 'O'],
#    ['呕吐', 'Symptom'],
#    ['量非常大的话就要给宝贝空肚子的奥，至少2小时不要喝水不要吃奶的', 'O']],
#   [['医生：宝贝', 'O'], ['拉肚子', 'Symptom'], ['到今天为止总共第几天了呢', 'O']],
#   [['患者：现在不敢喂多，但吃不饱宝宝又会闹，就90毫升，加点水这样。', 'O']],
#   [['医生：嗯嗯，这个时候您按需哺乳就可以，能喝多少喝多少别强喂就可以的', 'O']],
#   [['医生：宝贝大便的话现在一天多少次呢？', 'O']],
#   [['患者：好的好的', 'O']],
#   [['医生：宝贝到今天为止', 'O'], ['拉肚子', 'Symptom'], ['总共几天了呢？', 'O']],
#   [['患者：多多少少十来次', 'O']],
#   [['医生：大便什么样子的呢？除了', 'O'],
#    ['浠水', 'Symptom'],
#    ['之外，大便颜色正常吗？有没有', 'O'],
#    ['粘液', 'Symptom'],
#    ['脓血', 'Symptom'],
#    ['之类呢？有没有未消化的', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['呢？', 'O']],
#   [['患者：', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['有', 'O'],
#    ['粘液', 'Symptom'],
#    ['有，颜色金黄', 'O']],
#   [['医生：嗯嗯，尿量可以吗？', 'O']],
#   [['患者：尿也多', 'O']],
#   [['医生：嗯嗯，目前精神状态好尿量多的话就问题不大的！', 'O']],
#   [['医生：期间看过医生吗？', 'O']],
#   [['患者：没有，精神跟往常一样，', 'O']],
#   [['医生：宝贝目前的话大便的情况主要是一个', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的表现，', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的话可能受凉或者胃肠功能弱都可能引起来', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的，治疗的原则一般就是调节胃肠功能的治疗原则的奥', 'O']],
#   [['医生：宝贝用', 'O'], ['妈咪爱', 'Drug'], ['几天了呢？症状是有点好转了，对吗', 'O']],
#   [['患者：怎么调，', 'O'], ['妈咪爱', 'Drug'], ['有吃这两天', 'O']],
#   [['患者：吃了三天，好点不明显', 'O']],
#   [['目前的病情又比较稳定，所以我建议可以继续给宝贝巩固点', 'O'], ['妈咪爱', 'Drug'], ['调节胃肠功能', 'O']],
#   [['医生：宝妈除了注意饮食之外，多给宝贝热敷一下肚子，顺时针揉揉肚子，别着凉，换尿布之类的快点别着凉肚子，饮食能吃多少吃多少别强喂，奶粉的话能吃多少吃多少别强喂，奶粉别太凉了！',
#     'O']],
#   [['医生：吃着', 'O'],
#    ['益生菌', 'Drug_Category'],
#    ['观察两天，大便次数大便性状不缓解或者加重及时带宝贝去儿内科就诊', 'O'],
#    ['查', 'Medical_Examination'],
#    ['个', 'O'],
#    ['大便常规', 'Medical_Examination'],
#    ['明确一下病因，需不需要调整用药，根据结果对症处理，', 'O'],
#    ['精神状态差', 'Symptom'],
#    ['，超过8小时没尿的话就可以及时带宝贝去儿内科就诊', 'O'],
#    ['补液', 'Operation'],
#    ['对症治疗了，防止宝贝', 'O'],
#    ['脱水', 'Symptom'],
#    ['电解质紊乱', 'Symptom'],
#    ['的奥！', 'O']],
#   [['患者：', 'O'], ['妈咪爱', 'Drug'], ['一天吃多少较好，我给一天两次，一次一包会不会多了。', 'O']],
#   [['医生：目前的话不是没有效果，是好转了，因为这个会有一个过程的，不可能用上之后症状立马就消失的奥', 'O']],
#   [['医生：这个', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['的话按照正常量的话是可以的，这个根据体重和宝贝实际情况，您最好在面诊医生那里确定一下安全性的奥', 'O']],
#   [['患者：好的谢谢医生', 'O']],
#   [['医生：孩子', 'O'], ['拉肚子', 'Symptom'], ['总共几天了呢？', 'O']],
#   [['患者：有十天了', 'O']],
#   [['医生：孩子大便颜色呢？', 'O'],
#    ['浠水便', 'Symptom'],
#    ['吗？大便有未消化的', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['吗？', 'O']],
#   [['医生：十几天大便次数缓解了吗？', 'O']],
#   [['患者：没有', 'O'], ['奶瓣', 'Symptom']],
#   [['医生：孩子精神状态怎么样呢？', 'O']],
#   [['患者：缓解一点儿了，', 'O']],
#   [['医生：期间看过几次医生呢？', 'O']],
#   [['患者：孩子的精神状态很好，就是他，十天了已经，前几天一直是三四次，这两天是两三次，我们给吃', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['吃了有五天，', 'O']],
#   [['患者：是不是特别严重所以还没有去看过医生，', 'O']],
#   [['患者：（空）', 'O']],
#   [['患者：孩子大便是这个样子', 'O']],
#   [['医生：孩子这个目前的症状主要是', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的表现，主要是由于着凉，饮食不当等因素引起来的，治疗原则主要是调节胃肠功能的治疗原则', 'O']],
#   [['患者：不是', 'O'], ['肠炎', 'Symptom'], ['吗', 'O']],
#   [['患者：吃什么药昵，医生', 'O']],
#   [['医生：孩子', 'O'],
#    ['肠炎', 'Symptom'],
#    ['确诊的话得', 'O'],
#    ['查', 'Medical_Examination'],
#    ['大便常规', 'Medical_Examination'],
#    ['才能确定的', 'O']],
#   [['患者：吃', 'O'], ['妈咪爱', 'Drug'], ['也没有好转', 'O']],
#   [['医生：孩子现在大便看着是有', 'O'], ['消化不良', 'Symptom'], ['的表现的', 'O']],
#   [['患者：那我们有什么注意的吗', 'O']],
#   [['患者：需要吃些什么药能缓解', 'O']],
#   [['医生：孩子', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['时间比较长了，大便次数有所缓解了，大便次数恢复点了，胃肠功能没有完全恢复，精神状态还是可以的，用着', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['调节胃肠功能效果不好', 'O']],
#   [['患者：是的亲，用', 'O'], ['妈咪爱', 'Drug'], ['不是太有效', 'O']],
#   [['医生：孩子现在精神状态好，病情还是比较稳定的，孩子', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['时间长，用', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['缓解不明显，胃肠功能修复比较慢，我建议带着孩子去儿内科就诊给孩子', 'O'],
#    ['查', 'Medical_Examination'],
#    ['个', 'O'],
#    ['大便常规', 'Medical_Examination'],
#    ['，看一下大便的情况，根据结果对症治疗，需不需要调整用药', 'O']],
#   [['医生：这样我们用药也是比较明确，指导我们用药，用药比较安全', 'O']],
#   [['患者：现在医院都放假呀，我带着孩子大便去行吗？不用带孩子吧', 'O']],
#   [['医生：孩子吃饭注意饮食，清淡饮食为主，别吃凉的东西，多喝点温水，肚子别着凉，多热敷一下肚子，揉揉肚子', 'O']],
#   [['患者：现在只吃奶粉', 'O']],
#   [['医生：最好带着孩子吧，医院没有放假的，都是24小时值班的！主要是时间比较长了，胃肠功能修复不好，', 'O'],
#    ['查', 'Medical_Examination'],
#    ['个', 'O'],
#    ['大便常规', 'Medical_Examination'],
#    ['明确一下病因，根据结果对症处理', 'O']],
#   [['医生：奶粉别吃凉的，吃奶别吞进去空气', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：孩子一定多喝点温水，可以在水里少放点盐，防止', 'O'], ['电解质紊乱', 'Symptom']],
#   [['患者：好的', 'O']],
#   [['医生：孩子如果胃肠功能有影响别强喂奶粉！', 'O']],
#   [['患者：好的，大夫', 'O']],
#   [['医生：如您对我的解答满意，之后您或家人若有相关问题，欢迎再次找我咨询，我会努力为您解答，谢谢！', 'O']],
#   [['患者：谢谢', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：你好孩子', 'O'], ['咳嗽', 'Symptom'], ['多长时间了', 'O']],
#   [['患者：有四五天了', 'O']],
#   [['医生：有', 'O'], ['发热', 'Symptom'], ['吗', 'O']],
#   [['患者：前几天不厉害', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：昨天晚上', 'O'],
#    ['咳', 'Symptom'],
#    ['的厉害，一', 'O'],
#    ['咳', 'Symptom'],
#    ['起来就停不下来', 'O']],
#   [['医生：有做过什么检查吗', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：孩子小时候', 'O'],
#    ['湿疹', 'Symptom'],
#    ['重不重平时易', 'O'],
#    ['过敏', 'Symptom'],
#    ['吗', 'O']],
#   [['患者：', 'O'], ['咳', 'Symptom'], ['过一阵睡觉了就没事了', 'O']],
#   [['患者：不', 'O'], ['过敏', 'Symptom'], ['啊', 'O']],
#   [['医生：孩子经常', 'O'], ['咳嗽', 'Symptom'], ['吗', 'O']],
#   [['患者：不是', 'O']],
#   [['医生：如果只是这一次出现这种情况的话最好带孩子去', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['一下，让医生', 'O'],
#    ['听', 'Medical_Examination'],
#    ['一下', 'O'],
#    ['肺部', 'Medical_Examination'],
#    ['有没有问题，另外', 'O'],
#    ['查', 'Medical_Examination'],
#    ['下', 'O'],
#    ['支原体', 'Medical_Examination'],
#    ['血常规', 'Medical_Examination']],
#   [['患者：嗯', 'O']],
#   [['患者：和吃东西有管吗', 'O']],
#   [['医生：给孩子吃什么东西了', 'O']],
#   [['患者：前两天吃了药，有好转，', 'O']],
#   [['患者：苹果，梨，还有西瓜，还有肉', 'O']],
#   [['医生：这些东西与', 'O'], ['咳嗽', 'Symptom'], ['应该问题不大的', 'O']],
#   [['医生：孩子前一段时间吃什么药了吃了多长时间', 'O']],
#   [['患者：吃的', 'O'], ['浦地蓝消炎口服液', 'Drug'], ['和', 'O'], ['咳嗽药', 'Drug_Category']],
#   [['患者：吃了三天', 'O']],
#   [['医生：目前这种情况可以再给他吃几天药物然后让孩子勤喝水观察一下今晚如果', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['还严重的话要看医生', 'O']],
#   [['患者：嗯嗯好的，吃什么药好', 'O']],
#   [['医生：前几天你吃', 'O'],
#    ['蒲地蓝', 'Drug'],
#    ['和', 'O'],
#    ['止咳药', 'Drug_Category'],
#    ['有效果可以接着吃两天的', 'O']],
#   [['医生：至于', 'O'],
#    ['消炎药', 'Drug_Category'],
#    ['类的要根据', 'O'],
#    ['血', 'Medical_Examination'],
#    ['化验', 'Medical_Examination'],
#    ['决定的', 'O']],
#   [['患者：嗯嗯好的', 'O']],
#   [['患者：吃什么饭好呢', 'O']],
#   [['医生：平时正常饮食就可以清淡易消化的', 'O']],
#   [['医生：不要吃的过多过杂', 'O']],
#   [['患者：嗯', 'O']],
#   [['医生：还有其他问题吗没有的话我关了', 'O']],
#   [['患者：吃鸡蛋行吗', 'O']],
#   [['医生：没有', 'O'], ['过敏', 'Symptom'], ['可以的', 'O']],
#   [['患者：嗯好的谢谢', 'O']],
#   [['医生：你好，目前都在什么医院治疗，还是私人诊所', 'O']],
#   [['患者：私人的', 'O']],
#   [['医生：是吧，一般正规医院，用', 'O'], ['灌肠', 'Operation'], ['治疗方式少', 'O']],
#   [['医生：目前治疗效果怎样，有效吗', 'O']],
#   [['患者：我家孩子每次有炎症都', 'O'], ['肚子疼', 'Symptom'], ['，腹腔淋巴肿大', 'O']],
#   [['医生：做过', 'O'],
#    ['腹部彩超', 'Medical_Examination'],
#    ['吗，有', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['单的话，帮你看看', 'O']],
#   [['患者：效果不错，一般两天就好了，但这次一天两次大便，', 'O'], ['稀', 'Symptom']],
#   [['患者：没有。', 'O']],
#   [['患者：那还是去大医院查查？', 'O']],
#   [['医生：有效果就好，你目前有哪方面疑问', 'O']],
#   [['患者：会不会灌坏了，把孩子', 'O']],
#   [['患者：网上总说很多负面', 'O']],
#   [['患者：吓人', 'O']],
#   [['医生：多次的', 'O'], ['灌肠', 'Operation'], ['，会对肠黏膜造成损伤，正规医院都不用这个治疗手段', 'O']],
#   [['患者：我家孩子免疫力低', 'O']],
#   [['患者：每次', 'O'], ['打针', 'Operation'], ['七天以上', 'O']],
#   [['医生：建议正规公立医院诊治，可以吃点', 'O'], ['增强抵抗力', 'Drug_Category'], ['药物', 'O']],
#   [['患者：越打越没抵抗力', 'O']],
#   [['患者：孩子没脾', 'O']],
#   [['医生：不一定非得', 'O'],
#    ['打针', 'Operation'],
#    ['，一些轻症的', 'O'],
#    ['支气管炎', 'Symptom'],
#    ['，可以口服药', 'O']],
#   [['医生：没脾脏吗', 'O']],
#   [['患者：药吃过很多增强', 'O']],
#   [['患者：对，没脾脏', 'O']],
#   [['医生：怎么没有呢，切掉了吗', 'O']],
#   [['患者：对，', 'O']],
#   [['患者：破裂', 'O']],
#   [['医生：呃，脾破裂很危险，那样是会影响一些抵抗力的', 'O']],
#   [['患者：哎，不然不会选', 'O'], ['灌肠', 'Operation']],
#   [['医生：那样子，主要还在日常预防少生病', 'O']],
#   [['医生：也不用吃药', 'O'], ['打针', 'Operation']],
#   [['患者：去年在医院吃药，也是元旦前，', 'O'],
#    ['发烧', 'Symptom'],
#    ['三十八度', 'Symptom'],
#    ['就', 'O'],
#    ['抽', 'Symptom'],
#    ['了，', 'O'],
#    ['血项', 'Medical_Examination'],
#    ['三万。后来打了半个月针', 'O']],
#   [['医生：感染太重了', 'O']],
#   [['医生：很少见这么高', 'O'], ['血象', 'Medical_Examination']],
#   [['患者：今天灌两次，明天一天就能好，没什么问题吧', 'O']],
#   [['患者：害怕灌坏', 'O']],
#   [['医生：嗯，不要', 'O'], ['灌肠', 'Operation'], ['太多次', 'O']],
#   [['患者：是的我们也很小心', 'O']],
#   [['医生：一是对肠黏膜损伤，二是不知道用的哪些药', 'O']],
#   [['医生：诊所用药不太正规', 'O']],
#   [['患者：那个老大夫药很好用，好多人，各个地方的，离我们很远。挣很多钱呵呵', 'O']],
#   [['患者：', 'O'],
#    ['注射', 'Operation'],
#    ['抗生素', 'Drug_Category'],
#    ['不也杀', 'O'],
#    ['白细胞', 'Medical_Examination'],
#    ['吗', 'O']],
#   [['医生：是的，', 'O'],
#    ['抗生素', 'Drug_Category'],
#    ['会降', 'O'],
#    ['白细胞', 'Medical_Examination']],
#   [['患者：所以啊。', 'O'], ['灌肠', 'Operation'], ['真有致命的吗', 'O']],
#   [['医生：药物剂量掌握不好，是有危险的', 'O']],
#   [['患者：知道了，谢谢。', 'O']],
#   [['医生：好的，别客气，还有别的问题吗', 'O']],
#   [['患者：没了，呵呵', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：我是您的接诊医生', 'O']],
#   [['患者：您好', 'O']],
#   [['医生：宝贝主要是什么饮食呢？', 'O']],
#   [['患者：全母乳喂养', 'O']],
#   [['医生：最近吃奶量可以吗？有没有下降呢', 'O']],
#   [['患者：目前还没有正式添加辅食', 'O']],
#   [['医生：宝贝吃奶呛奶吗', 'O']],
#   [['患者：奶量和睡眠都正常', 'O']],
#   [['患者：不呛奶', 'O']],
#   [['医生：宝贝最近家里有人', 'O'], ['感冒', 'Symptom'], ['吗？', 'O']],
#   [['患者：爸爸感冒了', 'O']],
#   [['患者：没有特意隔离', 'O']],
#   [['医生：最近如果有人感冒的话带好口罩，避免交叉感染的', 'O']],
#   [['医生：宝贝总共', 'O'], ['咳嗽', 'Symptom'], ['几天了呢', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['一天能', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['几阵呢', 'O']],
#   [['患者：3月16号六个月', 'O'],
#    ['验血', 'Medical_Examination'],
#    ['，白血球有点高，过了两天有偶尔的', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['现在', 'O'],
#    ['痰量', 'Symptom'],
#    ['最近多了吗', 'O']],
#   [['患者：不是白血球高是', 'O'], ['白细胞', 'Medical_Examination'], ['高', 'O']],
#   [['患者：值是10.9', 'O']],
#   [['医生：时间太长了，这个结果没什么意义了', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['是一个过程，宝贝上', 'O'],
#    ['痰', 'Symptom'],
#    ['后', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状比较厉害，并不代表宝贝病情加重了，', 'O'],
#    ['痰', 'Symptom'],
#    ['液刺激的！不用担心，多给宝贝拍后背，促进', 'O'],
#    ['痰', 'Symptom'],
#    ['的排除奥！', 'O']],
#   [['患者：就是', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['的时候感觉孩子嗓子里有', 'O'],
#    ['痰', 'Symptom'],
#    ['，也没有发生憋气现象，喘气有点粗', 'O']],
#   [['医生：最近', 'O'],
#    ['痰量', 'Symptom'],
#    ['随着炎症渗出，', 'O'],
#    ['痰', 'Symptom'],
#    ['增多后刺激宝贝', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状比较明显的', 'O']],
#   [['医生：宝贝这个的话太小了所以', 'O'],
#    ['痰', 'Symptom'],
#    ['不会', 'O'],
#    ['吐', 'Symptom'],
#    ['，只能被', 'O'],
#    ['呕吐', 'Symptom'],
#    ['出去或者拉出去，所以多给宝贝拍背能把', 'O'],
#    ['痰', 'Symptom'],
#    ['呕吐', 'Symptom'],
#    ['出去也是比较好的，', 'O'],
#    ['痰', 'Symptom'],
#    ['咽下去之后胃肠功能会影响所以能吃多少吃多少别强喂奥', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：宝贝', 'O'], ['咳嗽', 'Symptom'], ['之后没有看过医生吧？', 'O']],
#   [['患者：没有，我觉得去医院太遭罪，首先得', 'O'],
#    ['验血', 'Medical_Examination'],
#    ['拍片子', 'Medical_Examination']],
#   [['患者：这种情况如果没有', 'O'],
#    ['发烧', 'Symptom'],
#    ['咳嗽', 'Symptom'],
#    ['也没有加重，是不是可以让孩子自愈呢，也能提高免疫力吧？', 'O']],
#   [['医生：宝贝这个目前症状宝贝可能诊断的', 'O'],
#    ['支气管炎', 'Symptom'],
#    ['，', 'O'],
#    ['支气管炎', 'Symptom'],
#    ['的话这个可能由于受凉或者感染引起来的，这个治疗的原则的话主要是', 'O'],
#    ['消炎止咳', 'Drug_Category'],
#    ['化痰治疗的奥！', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：宝贝目前的话', 'O'],
#    ['痰量增多', 'Symptom'],
#    ['炎症渗出增多，所以我建议给宝贝先', 'O'],
#    ['查', 'Medical_Examination'],
#    ['个', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['胸片', 'Medical_Examination'],
#    ['，排除一下', 'O'],
#    ['支气管炎', 'Symptom'],
#    ['，根据结果对症处理！这样能够指导我们用药，用药大体时间，用的药物也是比较对症的，宝贝恢复起来也是比较快的，利于宝贝恢复！', 'O']],
#   [['患者：需要去儿童医院吗？', 'O']],
#   [['医生：宝妈吃饭注意饮食，生冷辛辣刺激食物不能吃油腻食物不能吃，特别油腻食物容易', 'O'],
#    ['生痰', 'Symptom'],
#    ['的奥，多喝点温水，注意休息，别活动太厉害了奥，多给宝贝拍背，这个时候吃奶会有影响可能，能吃多少吃多少别强喂奥', 'O']],
#   [['医生：宝贝目前的', 'O'],
#    ['痰', 'Symptom'],
#    ['上来了', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状明显了，最好先做个', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['再用药，对宝贝来说也比较安全的，比较对症的奥！利于宝贝的恢复的奥', 'O']],
#   [['患者：是不是消炎累的药物都属于', 'O'], ['抗生素', 'Drug_Category'], ['呢？', 'O']],
#   [['医生：对的，看结果炎症具体大小，根据结果对症处理，这个面诊医生会根据情况给宝贝用的奥', 'O']],
#   [['患者：好的，谢谢您', 'O']],
#   [['医生：宝贝这个的', 'O'],
#    ['痰', 'Symptom'],
#    ['的目前拍上来的话就好了，这个病程总共大概需要7到10天时间，这个越小的宝贝恢复起来越慢宝贝', 'O'],
#    ['排痰', 'Symptom'],
#    ['比较慢，', 'O']],
#   [['患者：好的，明白了，非常感谢您', 'O']],
#   [['医生：所以您不用太担心了，目前的话宝贝情况还可以，做个检查明确一下病因，根据结果对症处理，再注意以上注意事项奥就可以，恢复的比较快点',
#     'O']],
#   [['患者：好，谢谢', 'O']],
#   [['医生：不客气的，祝宝贝健康', 'O']],
#   [['医生：您好', 'O']],
#   [['医生：', 'O'], ['绿色大便', 'Symptom']],
#   [['医生：有', 'O'], ['奶瓣', 'Symptom']],
#   [['医生：很可能是', 'O'], ['消化不良', 'Symptom']],
#   [['患者：拉丝状这么多', 'O']],
#   [['医生：', 'O'], ['粘液', 'Symptom'], ['多', 'O']],
#   [['医生：最近有没有受凉？', 'O'], ['感冒', 'Symptom'], ['？', 'O']],
#   [['患者：对', 'O']],
#   [['患者：', 'O'], ['感冒', 'Symptom']],
#   [['患者：一直', 'O'], ['低烧', 'Symptom']],
#   [['医生：哦，很可能是', 'O'],
#    ['感冒', 'Symptom'],
#    ['引起的', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的', 'O']],
#   [['医生：', 'O'], ['感冒', 'Symptom'], ['可以引起胃肠道功能低下', 'O']],
#   [['患者：那是不是辅食都不能添加了', 'O']],
#   [['医生：消化液分泌减少', 'O']],
#   [['患者：因为刚添加辅食的', 'O']],
#   [['医生：辅食先停下', 'O']],
#   [['医生：可以吃', 'O'], ['妈咪爱', 'Drug'], ['来调节肠道', 'O']],
#   [['医生：治疗', 'O'], ['消化不良', 'Symptom']],
#   [['医生：每次一包一天2次', 'O']],
#   [['患者：本来母乳的，我', 'O'], ['乳腺炎', 'Symptom'], ['发炎了，不能喂，开始给宝宝吃奶粉也有关系吗', 'O']],
#   [['医生：有关系。奶粉不好消化', 'O']],
#   [['医生：适应需要过程', 'O']],
#   [['患者：大便这样的还要多久才能正常啊', 'O']],
#   [['患者：看着有点吓人啊', 'O']],
#   [['医生：等', 'O'], ['感冒', 'Symptom'], ['好利索后过几天就好的', 'O']],
#   [['医生：宝宝食欲可以吗？', 'O']],
#   [['患者：还行，不过比之前减少很多', 'O']],
#   [['患者：不过也不算差', 'O']],
#   [['医生：哦，目前不算严重。可以吃药看看。假如出现精神食欲差，就有必要去医院儿科看看的', 'O']],
#   [['医生：不在了吗？', 'O']],
#   [['医生：有问题留言', 'O']],
#   [['医生：你好！', 'O']],
#   [['患者：两个多月', 'O'],
#    ['消化不良', 'Symptom'],
#    ['一吃就', 'O'],
#    ['吐', 'Symptom'],
#    ['怎么办、两三天没吃东西了也没有拉大便', 'O']],
#   [['医生：', 'O'], ['发烧', 'Symptom'], ['吗？', 'O']],
#   [['患者：不', 'O'], ['发烧', 'Symptom'], ['就是有点小', 'O'], ['感冒', 'Symptom']],
#   [['医生：每次都', 'O'], ['吐', 'Symptom'], ['出来吗？', 'O']],
#   [['患者：吃不到两分钟都', 'O'], ['吐', 'Symptom'], ['出来了', 'O']],
#   [['医生：有', 'O'], ['咳嗽', 'Symptom'], ['吗？', 'O']],
#   [['患者：有时候', 'O'], ['咳', 'Symptom']],
#   [['患者：很少', 'O']],
#   [['医生：一点儿奶也吃不了吗？', 'O']],
#   [['患者：吃但是一会都', 'O'], ['吐', 'Symptom'], ['出来了', 'O']],
#   [['医生：', 'O'], ['肚子涨', 'Symptom'], ['吗？', 'O']],
#   [['患者：应该没有', 'O']],
#   [['医生：大便什么样？', 'O']],
#   [['患者：前几天拉的有点儿', 'O'], ['拉肚子', 'Symptom'], ['、这几天都都没拉呢', 'O']],
#   [['医生：还是有精神吗？', 'O'], ['哭闹', 'Symptom'], ['吧。', 'O']],
#   [['患者：拉的像', 'O'], ['蛋花', 'Symptom'], ['一样', 'O']],
#   [['医生：孩子有精神吧，是不是', 'O'], ['哭闹', 'Symptom'], ['。', 'O']],
#   [['患者：有精神、就是晚上要抱、放床上就哭、白天就睡觉', 'O']],
#   [['医生：去医院', 'O'], ['检查', 'Medical_Examination'], ['过吗？', 'O']],
#   [['患者：去了说是', 'O'], ['消化不良', 'Symptom'], ['有点小', 'O'], ['感冒', 'Symptom']],
#   [['医生：吃过药了吗？', 'O']],
#   [['患者：开了', 'O'], ['醒脾养儿颗粒', 'Drug']],
#   [['医生：吃了几天了，效果怎么样。', 'O']],
#   [['患者：', 'O'], ['儿童回春颗粒', 'Drug']],
#   [['医生：', 'O'], ['呕吐', 'Symptom'], ['减轻吧', 'O']],
#   [['患者：从昨天到今天好像没什么效果', 'O']],
#   [['患者：还是一样的', 'O'], ['吐', 'Symptom']],
#   [['医生：根据你说的情况，我分析孩子还是有', 'O'], ['消化不良', 'Symptom'], ['的。', 'O']],
#   [['医生：一共吃了几天药啦', 'O']],
#   [['患者：帖', 'O'], ['止吐帖', 'Drug_Category'], ['也不管用', 'O']],
#   [['患者：今天两天', 'O']],
#   [['医生：孩子尿量少吗？', 'O']],
#   [['患者：不少', 'O']],
#   [['医生：可以适当的调整一下药物。', 'O']],
#   [['患者：几天都没拉大便了', 'O']],
#   [['医生：吃上', 'O'], ['吗咪爱', 'Drug'], ['助消化', 'Drug_Category'], ['的', 'O']],
#   [['患者：现在也有在吃', 'O'], ['妈咪爱', 'Drug'], ['的', 'O']],
#   [['医生：孩子小抵抗力差，如果', 'O'],
#    ['呕吐', 'Symptom'],
#    ['不止，会引起', 'O'],
#    ['脱水', 'Symptom'],
#    ['的。', 'O']],
#   [['患者：那怎么办呢', 'O']],
#   [['医生：如果是比较快还是静脉', 'O'], ['输液', 'Operation'], ['。', 'O']],
#   [['医生：吃药不见好转，孩子小会引起', 'O'], ['脱水', 'Symptom'], ['酸中毒。', 'O']],
#   [['医生：静脉', 'O'], ['输液', 'Operation'], ['效果还是比较快的。', 'O']],
#   [['患者：昨天医院也说让', 'O'], ['输液', 'Operation'], ['家人说孩子太小了', 'O']],
#   [['患者：好吧、今天不好就只有', 'O'], ['输夜', 'Operation'], ['了', 'O']],
#   [['医生：还是', 'O'], ['呕吐', 'Symptom'], ['不止，会引起其他疾病，以免耽误病情。', 'O']],
#   [['患者：好的、谢谢', 'O']],
#   [['医生：不客气的有问题及时联系', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：您好', 'O']],
#   [['患者：你好', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：宝宝现在晚上睡觉', 'O'], ['咳嗽', 'Symptom'], ['吗', 'O']],
#   [['患者：帮我看看', 'O'], ['化验', 'Medical_Examination'], ['结果', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻涕', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['不', 'O']],
#   [['患者：', 'O'], ['咳嗽', 'Symptom'], ['好多了', 'O']],
#   [['患者：就是', 'O'], ['喉咙呼吸声', 'Symptom'], ['大', 'O']],
#   [['医生：这个', 'O'], ['血常规', 'Medical_Examination'], ['问题不大', 'O']],
#   [['医生：', 'O'], ['呼噜呼噜', 'Symptom'], ['的吗', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：有', 'O'], ['丝丝的声音', 'Symptom'], ['吗', 'O']],
#   [['患者：这个', 'O'], ['化验', 'Medical_Examination'], ['结果是针对什么的', 'O']],
#   [['患者：有吧', 'O']],
#   [['医生：原来有', 'O'], ['丝丝的声音', 'Symptom'], ['吗', 'O']],
#   [['患者：一直都有点，好像喉咙有', 'O'], ['痰', 'Symptom'], ['一样', 'O']],
#   [['医生：这个', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['主要是看那个', 'O'],
#    ['白细胞', 'Medical_Examination'],
#    ['的还化验别的了吗？', 'O']],
#   [['医生：', 'O'], ['胸片', 'Medical_Examination'], ['没，', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻涕', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['不', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：说是', 'O'], ['气管炎', 'Symptom']],
#   [['患者：', 'O'], ['雾化', 'Operation'], ['有用吗', 'O']],
#   [['医生：现在打什么', 'O'], ['点滴', 'Operation'], ['呢', 'O']],
#   [['医生：局部', 'O'],
#    ['雾化', 'Operation'],
#    ['止咳化痰', 'Drug_Category'],
#    ['效果好', 'O']],
#   [['医生：副作用小', 'O']],
#   [['医生：宝宝现在怎么样了？', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：宝宝是母乳喂养吗？', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：精神吃奶好吗？', 'O']],
#   [['患者：平常一样', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：原来1天大便几次？', 'O']],
#   [['患者：今天有一次边吃边', 'O'], ['哭', 'Symptom']],
#   [['患者：四次左右', 'O']],
#   [['医生：哦，', 'O']],
#   [['医生：1天增加了2次', 'O']],
#   [['医生：现在体温正常吗？', 'O']],
#   [['患者：体温正常', 'O']],
#   [['医生：嗯，宝宝', 'O'], ['肚子胀', 'Symptom'], ['吗', 'O']],
#   [['患者：不', 'O'], ['胀', 'Symptom']],
#   [['医生：哦，如果宝宝下次大便还有这种情况，建议给宝宝', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['一下', 'O'],
#    ['大便常规', 'Medical_Examination']],
#   [['患者：今天有两次这种情况了', 'O']],
#   [['医生：哦，', 'O']],
#   [['医生：继续观察一下，如果明天还有，就留', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['化验', 'Medical_Examination'],
#    ['一下', 'O']],
#   [['医生：1个小时之内的大便都可以', 'O'], ['化验', 'Medical_Examination'], ['的', 'O']],
#   [['患者：好的，谢谢医生', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['患者：我昨天吃了血蛤有关系吗', 'O']],
#   [['医生：考虑关系不大', 'O']],
#   [['患者：喔喔，好的', 'O']],
#   [['医生：好的，给宝宝喂奶时，注意洗干净乳头', 'O']],
#   [['医生：注意腹部保暖', 'O']],
#   [['医生：可以口服', 'O'], ['妈咪爱', 'Drug']],
#   [['患者：好的', 'O']],
#   [['医生：好，有事联系', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：祝宝宝健康快乐成长', 'O']],
#   [['医生：您好，我是您的辅诊医生，需要询问几个问题，才能更好的评估孩子情况，您还在吗？', 'O']],
#   [['医生：宝宝纯母乳喂养吗', 'O']],
#   [['患者：嗯是的', 'O']],
#   [['医生：宝宝大便什么样子', 'O']],
#   [['医生：一天拉几次', 'O']],
#   [['患者：黄色', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：宝宝', 'O'], ['肚子胀', 'Symptom'], ['吗', 'O']],
#   [['患者：有点', 'O'], ['绿', 'Symptom']],
#   [['医生：一天拉几次', 'O']],
#   [['患者：5，6次吧', 'O']],
#   [['患者：', 'O'], ['放屁', 'Symptom'], ['多', 'O']],
#   [['医生：量多吗？', 'O']],
#   [['医生：宝宝以前大便什么样子', 'O']],
#   [['患者：泡沫大便', 'O']],
#   [['患者：不多', 'O']],
#   [['医生：宝宝有', 'O'], ['消化不良', 'Symptom'], ['症状的', 'O']],
#   [['医生：母亲有没有吃不好消化的食物?', 'O']],
#   [['患者：都是稀泡沫', 'O']],
#   [['患者：只吃面和和小米粥啊', 'O']],
#   [['医生：泡沫一般是未消化的脂肪粒', 'O']],
#   [['医生：有没有吃凉的或者隔夜菜', 'O']],
#   [['患者：应该怎么办', 'O']],
#   [['医生：可以给宝贝顺时针揉一下肚子或者热敷一下，用热水袋，注意不要烫伤。', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：都是现做的饭', 'O']],
#   [['医生：喂完抱一会宝宝，拍出饱嗝，不要让宝贝吃太急，尽量右侧卧位房宝宝', 'O']],
#   [['患者：奥', 'O']],
#   [['患者：不要紧么', 'O']],
#   [['医生：吃奶后半小时按摩', 'O']],
#   [['患者：好的??', 'O']],
#   [['医生：嗯嗯', 'O']],
#   [['医生：注意饮食卫生', 'O']],
#   [['医生：喂奶前后擦拭乳头哦', 'O']],
#   [['医生：祝宝宝健康成长', 'O']],
#   [['医生：您还有疑问吗?', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：可能您在忙，稍后有疑问可以给我留言', 'O']],
#   [['医生：如果您超过五分钟不回复，系统会自动关闭对话，您还在吗？', 'O']],
#   [['医生：你好', 'O']],
#   [['患者：你好', 'O']],
#   [['医生：请问宝宝', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['血', 'Medical_Examination'],
#    ['了吗？', 'O']],
#   [['患者：化验了', 'O']],
#   [['医生：方便把', 'O'], ['化验', 'Medical_Examination'], ['单拍照发过来吗？', 'O']],
#   [['患者：好', 'O']],
#   [['医生：嗯', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：孩子是有明确的', 'O'],
#    ['细菌感染', 'Symptom'],
#    ['，用', 'O'],
#    ['头孢', 'Drug_Category'],
#    ['是合适的，这三样药孩子以前有吃过吗？', 'O']],
#   [['患者：今天一直', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['还给吃了', 'O'],
#    ['蒙脱石散', 'Drug'],
#    ['，但没有效果', 'O']],
#   [['患者：有吃过', 'O']],
#   [['医生：昨天之前大便怎么样？', 'O']],
#   [['患者：昨天有点', 'O'], ['拉肚子', 'Symptom'], ['没今天严重', 'O']],
#   [['医生：哦，大便有化验吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：今天', 'O'], ['拉', 'Symptom'], ['了几次？', 'O']],
#   [['患者：有十次左右', 'O']],
#   [['医生：有大便的照片吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'], ['大便很稀', 'Symptom'], ['吗？什么颜色？', 'O']],
#   [['患者：大便土黄色，', 'O'], ['浠水', 'Symptom']],
#   [['医生：', 'O'], ['蒙脱石散', 'Drug'], ['你具体是怎么喂的？', 'O']],
#   [['患者：一次三袋，冲水喝', 'O']],
#   [['医生：孩子今天精神、食欲怎么样？', 'O']],
#   [['患者：中午喝了一次，晚上饭后喝了一次', 'O']],
#   [['患者：食欲还可以', 'O']],
#   [['医生：', 'O'], ['蒙脱石散', 'Drug'], ['是需要在饭前空腹时吃才有止泻效果的。', 'O']],
#   [['患者：精神挺好的', 'O']],
#   [['患者：我都给她饭后吃了', 'O']],
#   [['医生：嗯，那是没有效果的', 'O']],
#   [['患者：那晚上还要给她吃吗', 'O']],
#   [['患者：需要吃别的药吗', 'O']],
#   [['医生：孩子在用药后出现', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，但是以前也吃过类似的药物，没有出现这种症状，不太考虑药物引起。首先需要在饭前空腹时吃', 'O'],
#    ['蒙脱石散', 'Drug'],
#    ['，同时可以口服', 'O'],
#    ['益生菌', 'Drug_Category'],
#    ['调理。', 'O']],
#   [['患者：', 'O'], ['消食片', 'Drug'], ['可以吗', 'O']],
#   [['医生：也可以的', 'O']],
#   [['医生：孩子目前的情况是考虑', 'O'],
#    ['消化不良', 'Symptom'],
#    ['的，在这期间饮食尽量要清淡一点，宜少食多餐，减轻胃肠道负担。', 'O']],
#   [['患者：那等下我再给她吃', 'O'],
#    ['蒙脱石散', 'Drug'],
#    ['和', 'O'],
#    ['消食片', 'Drug'],
#    ['吗', 'O']],
#   [['医生：好的', 'O']],
#   [['患者：好，谢谢了', 'O']],
#   [['医生：如果用药两天宝宝症状没有任何缓解，或者再次出现', 'O'], ['发热', 'Symptom'], ['，需要到医院复诊。', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：是今天刚开始发现的吗', 'O']],
#   [['医生：', 'O'], ['咽喉有充血', 'Symptom']],
#   [['患者：昨天', 'O'],
#    ['发烧', 'Symptom'],
#    ['，但是', 'O'],
#    ['退烧药', 'Drug_Category'],
#    ['吃了就', 'O'],
#    ['退', 'Symptom'],
#    ['了', 'O']],
#   [['医生：除了', 'O'],
#    ['发烧', 'Symptom'],
#    ['，有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['之类其他症状吗', 'O']],
#   [['患者：昨天', 'O'], ['喉咙没有充血', 'Symptom']],
#   [['患者：很少', 'O'], ['咳嗽', 'Symptom']],
#   [['医生：嗯，因为疾病是一个发展过程', 'O']],
#   [['患者：就是', 'O'], ['扁桃体发炎', 'Symptom'], ['还是其他什么病？', 'O']],
#   [['医生：', 'O'], ['扁桃体', 'Symptom'], ['白色小泡', 'O']],
#   [['患者：嗯，有三四个', 'O']],
#   [['医生：有化脓点吗', 'O']],
#   [['患者：拍照不好拍到', 'O']],
#   [['患者：好像没有', 'O']],
#   [['医生：是的，看不是很大出来', 'O']],
#   [['医生：那你要注意除', 'O'],
#    ['扁桃体炎', 'Symptom'],
#    ['外另一点是，', 'O'],
#    ['疱疹性咽峡炎', 'Symptom']],
#   [['医生：建议', 'O'],
#    ['查', 'Medical_Examination'],
#    ['个', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['看有没有并发感染', 'O']],
#   [['患者：吃了', 'O'],
#    ['消炎药', 'Drug_Category'],
#    ['后', 'O'],
#    ['发烧', 'Symptom'],
#    ['没有超过', 'O'],
#    ['38度', 'Symptom'],
#    ['了', 'O']],
#   [['医生：吃的', 'O'], ['头孢', 'Drug_Category'], ['是吗', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：如果是化脓性', 'O'], ['扁桃体炎', 'Symptom'], ['是对的', 'O']],
#   [['医生：是给医生看过，开药的吗', 'O']],
#   [['患者：要是', 'O'], ['疱疹', 'Symptom'], ['那个呢', 'O']],
#   [['患者：不是，家里备的药', 'O']],
#   [['医生：如果吃', 'O'],
#    ['头孢', 'Drug_Category'],
#    ['有效果那化脓性', 'O'],
#    ['扁桃体炎', 'Symptom'],
#    ['也是比较可能', 'O']],
#   [['患者：现在就是有时还有点', 'O'], ['低烧', 'Symptom'], ['，', 'O'], ['37.6', 'Symptom']],
#   [['医生：', 'O'],
#    ['38.5', 'Symptom'],
#    ['℃以下可以不用', 'O'],
#    ['退烧药', 'Drug_Category'],
#    ['的', 'O']],
#   [['患者：没有用的', 'O']],
#   [['医生：', 'O'], ['低烧', 'Symptom'], ['话，一般也会两三天', 'O']],
#   [['医生：是的，主要是物理降温为主', 'O']],
#   [['医生：如果家里备的药吃了有效，可以先吃着观察一下', 'O']],
#   [['患者：炎症好的', 'O']],
#   [['医生：但是要按剂量来，按上面说明书', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：炎症得三四天才能消吧', 'O']],
#   [['医生：如果没有感觉好转，是建议能够去看一下', 'O']],
#   [['医生：一般三四天，如果没有好转是要去看', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：谢谢', 'O']],
#   [['医生：您好', 'O']],
#   [['患者：你好', 'O']],
#   [['患者：我家宝宝怎么回事', 'O']],
#   [['医生：怎么最近的话有末有受凉呀她这个大便带粘液你一天大便几次，', 'O']],
#   [['患者：3到4次', 'O']],
#   [['医生：我之前的话他大病一般一天几次啊，', 'O']],
#   [['患者：1到2次', 'O']],
#   [['患者：就是', 'O'], ['绿', 'Symptom']],
#   [['医生：就大便次数增多这个考虑是副业，嗯要是明天的话要', 'O'],
#    ['查', 'Medical_Examination'],
#    ['大便常规', 'Medical_Examination'],
#    ['，', 'O']],
#   [['患者：还有点沫沫', 'O']],
#   [['医生：那你最近的话给宝宝多吃一点白粥米汤男少喝一点然后吃一点', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['或者', 'O'],
#    ['益生菌', 'Drug_Category'],
#    ['类的菜，', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：好几天了', 'O']],
#   [['医生：（空）', 'O']],
#   [['医生：吃好几天了如果你要出来的话最好吃腹泻奶粉就是问问棠配方奶粉，', 'O']],
#   [['患者：拉的太', 'O'], ['绿', 'Symptom'], ['了', 'O']],
#   [['医生：对于因为主要考虑还拿了个病毒的话那就是那个水塘没可能又缺乏但是母乳喝一段奶粉转就是还有点疼，', 'O']],
#   [['患者：不能喝母乳了？', 'O']],
#   [['患者：可是孩子不喝奶粉', 'O']],
#   [['医生：喝母乳的话就吃点', 'O'], ['乳糖酶', 'Drug'], ['，但是文化可能么有了这个我现在不好，', 'O']],
#   [['医生：最好是少喝奶粉然后观察一下因为了时间太长了可能有', 'O'], ['乳糖酶', 'Drug'], ['的缺乏，', 'O']],
#   [['患者：没喝过奶粉', 'O']],
#   [['患者：一直母乳喂养', 'O']],
#   [['医生：那最好吃', 'O'], ['乳糖酶', 'Drug'], ['，就是母乳前吃', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：婴儿店里有卖吗', 'O']],
#   [['医生：有的，大的母婴店有卖的', 'O']],
#   [['患者：哦哦！谢谢', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：您可在咨询结束后点击（首页），在首页里找到（康复记录），在康复记录里找到我然后点（再次咨询)', 'O']],
#   [['医生：祝宝宝早日康复', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：刚好你看下有没其它问题我没我的话我就结束服务了，', 'O']],
#   [['医生：如果后面还有问题的话你再给我发，再问我，', 'O']],
#   [['患者：恩，好的', 'O']],
#   [['医生：嗯嗯，祝新年快乐', 'O']],
#   [['医生：????', 'O']],
#   [['患者：新年快乐', 'O']],
#   [['医生：拜拜', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：在吗', 'O']],
#   [['医生：为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合。', 'O']],
#   [['患者：在', 'O']],
#   [['患者：您好', 'O']],
#   [['医生：宝宝病了几天了', 'O']],
#   [['患者：四天了', 'O']],
#   [['医生：宝宝', 'O'], ['咳嗽', 'Symptom'], ['是一声声还是一顿顿的', 'O']],
#   [['患者：声', 'O']],
#   [['医生：宝宝', 'O'], ['咳嗽', 'Symptom'], ['是白天严重还是夜间严重', 'O']],
#   [['患者：就昨天没有', 'O'], ['流鼻涕', 'Symptom'], ['咳嗽', 'Symptom'], ['，今天又开始了', 'O']],
#   [['医生：有没有', 'O'], ['发热', 'Symptom'], ['？', 'O']],
#   [['患者：没有', 'O'], ['发烧', 'Symptom']],
#   [['患者：精神正常', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['有', 'O'], ['痰', 'Symptom'], ['吗？', 'O']],
#   [['患者：', 'O'], ['咳嗽', 'Symptom'], ['不多', 'O']],
#   [['医生：有没有', 'O'], ['喘息', 'Symptom'], ['症状', 'O']],
#   [['患者：就是有', 'O'], ['痰', 'Symptom']],
#   [['患者：说是', 'O'], ['咽炎', 'Symptom']],
#   [['医生：宝宝大便正常吗', 'O']],
#   [['患者：', 'O'], ['鼻子不通气', 'Symptom'], ['，晚上睡觉用嘴呼吸', 'O']],
#   [['患者：正常', 'O']],
#   [['医生：饮食怎么样，宝宝精神状况如何？', 'O']],
#   [['患者：正常', 'O']],
#   [['医生：从描述症状考虑宝宝', 'O'], ['支气管炎', 'Symptom']],
#   [['患者：是不是这三种药得换成别样的', 'O']],
#   [['医生：建议带宝宝到公立医院儿科找医生再听一下气管，合理', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['一下', 'O'],
#    ['胸片', 'Medical_Examination']],
#   [['医生：了解一下肺部和气管炎症情况', 'O']],
#   [['患者：嗯，还是得去医院', 'O']],
#   [['医生：如果', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['不严重可以加用', 'O'],
#    ['化痰止咳药', 'Drug_Category'],
#    ['物', 'O']],
#   [['医生：从描述症状建议合理', 'O'], ['检查', 'Medical_Examination'], ['一下', 'O']],
#   [['患者：（空）', 'O']],
#   [['患者：什么药', 'O']],
#   [['医生：比如', 'O'], ['肺力咳', 'Drug'], ['，', 'O'], ['氨溴特罗', 'Drug']],
#   [['患者：消炎的哪？', 'O']],
#   [['医生：可以继续应用', 'O'], ['红霉素', 'Drug_Category']],
#   [['患者：好吧，谢谢', 'O']],
#   [['医生：不用客气，祝宝宝健康成长', 'O']],
#   [['医生：还有其他问题吗？', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['患者：再见', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：如果没有其他问题，那就结束了，再见', 'O']],
#   [['医生：你好宝宝', 'O'], ['拉肚子', 'Symptom'], ['有多少天呢？大便一天有多少次呢？', 'O']],
#   [['医生：有带孩子去看过医生吗？', 'O']],
#   [['患者：昨天开始的，一天十几次了，', 'O']],
#   [['医生：大便成形吗？是什么颜色的？', 'O']],
#   [['患者：没有去过医院', 'O']],
#   [['患者：没有我这小诊所', 'O']],
#   [['医生：孩子现在精神反应怎么样？体温是正常的吗？小便的量和平常相比有没有明显的减少？', 'O']],
#   [['医生：附近没有大一点的医院吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：小便有减少', 'O']],
#   [['医生：你好，我需要详细的掌握一些关于孩子的病情，所以才能更好的作出判断。希望你能配合。', 'O']],
#   [['医生：孩子目前精神怎么样？有测过体温吗？', 'O']],
#   [['患者：体温还好老哭', 'O']],
#   [['医生：你好，根据你的描述，孩子一天，大便次数有十多次，然后目前', 'O'],
#    ['小便量明显减少', 'Symptom'],
#    ['，并且，伴', 'O'],
#    ['哭闹', 'Symptom'],
#    ['。孩子的这些表现提示目前因为反复', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，存在', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况。需要积极的做处理。给孩子喂了什么药呢？', 'O']],
#   [['医生：孩子哭的时候眼泪多不多？你可以摸一下孩子的前囟，有没有明显的凹陷？', 'O']],
#   [['医生：', 'O'],
#    ['腹泻', 'Symptom'],
#    ['它分为多种原因有可能是感染性的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，也有可能是因为喂养方式不当导致的非感染性腹泻，根据程度来划分的话，分为轻度中度和重度。会办法不同程度的，', 'O'],
#    ['脱水', 'Symptom'],
#    ['和电解质失衡。', 'O']],
#   [['患者：现在吃点', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['，还有', 'O'],
#    ['四菇汤', 'Drug'],
#    ['，', 'O'],
#    ['蒙脱石散', 'Drug']],
#   [['医生：是去你附近诊所开的药还是自己买的？吃了药以后孩子大便。次数有明显的好转吗？', 'O']],
#   [['患者：小孩子吃的是奶粉', 'O']],
#   [['医生：奶具都严格消毒。没有？', 'O']],
#   [['患者：是去诊所问医生啦的', 'O']],
#   [['患者：有啊', 'O']],
#   [['医生：一般轻型的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['吃', 'O'],
#    ['妈咪爱', 'Drug'],
#    ['蒙脱石散', 'Drug'],
#    ['孩子的大便是应该有好转的。', 'O']],
#   [['患者：今天刚刚吃的', 'O']],
#   [['不太好，有点吵闹，小便也明显减少了。考虑有', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况，需要查一下', 'O'],
#    ['电解质', 'Medical_Examination'],
#    ['。看是否存在', 'O'],
#    ['电解质', 'Medical_Examination'],
#    ['失衡。', 'O']],
#   [['医生：因为不同原因引起的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，治疗的方式还是有差异的。首先我们需要排除是否是感染性的原因。如果', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['结果没有问题的话，我们对症处理就可以了。', 'O']],
#   [['患者：大便和他拉出来的', 'O'],
#    ['鼻涕', 'Symptom'],
#    ['一样的是分开的，好像有点带不明显的', 'O'],
#    ['血丝', 'Symptom']],
#   [['医生：这种情况的话，就更需要', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['个', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['。家里去附近稍微大一点的医院，需要多长时间呀？', 'O']],
#   [['患者：要两个小时', 'O']],
#   [['医生：主要是孩子太小了，只有一个多月，反复', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，容易造成', 'O'],
#    ['脱水，', 'Symptom'],
#    ['脱水', 'Symptom'],
#    ['的话，孩子的精神就会越来越差，是比较危险的？', 'O']],
#   [['患者：是啊医生', 'O']],
#   [['医生：那个规模稍微大一点的医院是什么级别的医院呀？一般二甲以上医院晚上都可以看的有急诊。', 'O']],
#   [['医生：所以我们要比其他孩子要更引起重视', 'O']],
#   [['患者：好的我知道了谢谢你医生', 'O']],
#   [['医生：', 'O'],
#    ['腹泻', 'Symptom'],
#    ['它本身并不是十分可怕，严重的是它所造成的并发症。一定要及时处理，特别是这种小宝宝，不能拖的。', 'O']],
#   [['医生：还有，孩子', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['的', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['，尽量在一个小时之内。', 'O']],
#   [['医生：超过两个小时的', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['化验', 'Medical_Examination'],
#    ['出来是没有效的，结果也没有意义。', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：谢谢', 'O']],
#   [['患者：我去看看', 'O']],
#   [['医生：你们家去医院最快也要两个小时的话，我建议你先带孩子去医院，到了医院先', 'O'],
#    ['抽血', 'Medical_Examination'],
#    ['，孩子拉大便次数有这么多，应该在医院也会拉大便。', 'O']],
#   [['医生：尽量送取新鲜的大便标本。', 'O']],
#   [['医生：因为大便放久了，它会以滋生细菌和病毒。对结果造成干扰', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：好的，希望我能帮到你，早点带孩子去医院，因为孩子目前', 'O'],
#    ['精神不好', 'Symptom'],
#    ['，', 'O'],
#    ['脱水', 'Symptom'],
#    ['情况都比较明显', 'O']],
#   [['医生：你如果有其他的疑问可以过后找我也可以，我可以帮你分析一下，因为对', 'O'],
#    ['腹泻', 'Symptom'],
#    ['这一方面我还是比较有经验的。', 'O']],
#   [['患者：好', 'O']],
#   [['患者：谢谢了', 'O']],
#   [['医生：不用客气，如果你现在没有其她问题的话，就点击结束服务吧！我希望你从医院回来以后再次联系我，我也很关心孩子的问题。因为从我这边的话最早也只能明天联系到你。',
#     'O']],
#   [['医生：受系统的限制，我只能明天才能联系到你。', 'O']],
#   [['医生：先带孩子去医院就诊要紧。', 'O']],
#   [['医生：有任何疑问及时联系我，我看到了你的留言会及时回复你的。', 'O']],
#   [['医生：你好，孩子', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['大便', 'Medical_Examination'],
#    ['，', 'O'],
#    ['查', 'Medical_Examination'],
#    ['了', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['吗？', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合。', 'O']],
#   [['医生：在吗', 'O']],
#   [['患者：在', 'O']],
#   [['医生：宝宝', 'O'], ['流鼻涕', 'Symptom'], ['咳嗽', 'Symptom'], ['几天了', 'O']],
#   [['患者：3天', 'O']],
#   [['医生：有没有', 'O'], ['发热', 'Symptom']],
#   [['患者：之前', 'O'], ['发烧', 'Symptom'], ['3天', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['是一声声还是一顿顿的', 'O']],
#   [['患者：', 'O'], ['发热', 'Symptom'], ['后', 'O'], ['感冒', 'Symptom']],
#   [['患者：一声一声的', 'O']],
#   [['医生：从', 'O'], ['发热', 'Symptom'], ['到现在几天了', 'O']],
#   [['患者：6天', 'O']],
#   [['医生：是夜间严重还是白天', 'O'], ['咳嗽', 'Symptom'], ['严重', 'O']],
#   [['医生：有没有', 'O'], ['喘息', 'Symptom'], ['症状', 'O']],
#   [['患者：白天', 'O']],
#   [['医生：宝宝现在应用什么药物', 'O']],
#   [['医生：还在吗', 'O']],
#   [['患者：', 'O'], ['易思静', 'Drug']],
#   [['医生：还有吗', 'O']],
#   [['医生：', 'O'], ['易坦静', 'Drug']],
#   [['患者：', 'O'], ['罗红', 'Drug']],
#   [['患者：', 'O'], ['小葵花', 'Drug']],
#   [['医生：就这两种', 'O']],
#   [['患者：对', 'O']],
#   [['患者：3种', 'O']],
#   [['医生：有没有', 'O'], ['检查', 'Medical_Examination'], ['过', 'O']],
#   [['患者：没有，去年冬天有过', 'O'], ['肺炎', 'Symptom']],
#   [['医生：根据描述症状考虑宝宝', 'O'],
#    ['支气管炎', 'Symptom'],
#    ['可能性大，建议带宝宝到医院找医生听一下气管，最好做一下', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['和', 'O'],
#    ['CRP', 'Medical_Examination'],
#    ['，分析一下是', 'O'],
#    ['病毒感染', 'Symptom'],
#    ['还是', 'O'],
#    ['细菌感染', 'Symptom'],
#    ['，拍', 'O'],
#    ['胸片', 'Medical_Examination'],
#    ['检查', 'Medical_Examination'],
#    ['，了解一下肺部和气管炎症情况。', 'O']],
#   [['患者：去诊所听没啥事就回家了', 'O']],
#   [['医生：建议到公立医院规范', 'O'], ['检查', 'Medical_Examination']],
#   [['患者：嗯嗯好的', 'O']],
#   [['医生：祝宝宝健康成长', 'O']],
#   [['医生：还有其他问题吗？', 'O']],
#   [['患者：没了谢谢', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：你好，那说明宝宝好起来了呀', 'O']],
#   [['患者：可是拉的也太多了吧，吃了没多久就拉了，', 'O']],
#   [['患者：会不吸收营养吗', 'O']],
#   [['医生：一天4次，软的不是水样说明有好起来', 'O']],
#   [['医生：', 'O'], ['拉肚子', 'Symptom'], ['确实会影响营养吸收', 'O']],
#   [['患者：之前是', 'O'],
#    ['水样', 'Symptom'],
#    ['，这两天给她吃了', 'O'],
#    ['蒙脱石散', 'Drug'],
#    ['，就拉软的', 'O']],
#   [['医生：恩，宝宝现在吃的是母乳吗', 'O']],
#   [['患者：是的', 'O']],
#   [['患者：之前', 'O'], ['拉水', 'Symptom'], ['的时候一天一般是两次', 'O']],
#   [['医生：一天4次的大便不算次数很多', 'O']],
#   [['医生：疾病恢复有个过程，要慢慢好起来', 'O']],
#   [['医生：现在没有添加辅食吧？', 'O']],
#   [['患者：那还要吃药吗', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：恩，', 'O'], ['拉肚子', 'Symptom'], ['不要吃', 'O']],
#   [['医生：有吃', 'O'], ['益生菌', 'Drug_Category'], ['吗？', 'O']],
#   [['医生：小便跟平常差不多吗？', 'O']],
#   [['患者：有，没吃，一样', 'O']],
#   [['医生：可以给宝宝吃', 'O'], ['益生菌', 'Drug_Category']],
#   [['患者：吃了没用', 'O']],
#   [['医生：这个不会立竿见影，是属于调理的', 'O']],
#   [['患者：拉水拉了有20天，吃了药，开始就是吃', 'O'], ['益生菌', 'Drug_Category'], ['没用', 'O']],
#   [['患者：我担心药吃多了不好，前两天', 'O'], ['感冒', 'Symptom'], ['也吃了药', 'O']],
#   [['患者：现在早上起床总是会', 'O'], ['咳', 'Symptom'], ['几声', 'O']],
#   [['医生：', 'O'], ['蒙托石散', 'Drug'], ['的话如果水分还是有点多那就继续吃', 'O']],
#   [['医生：看大便水分情况', 'O']],
#   [['患者：有一次有一点点水，其她没有', 'O']],
#   [['医生：那可以不吃了', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：宝宝吃冰糖雪梨水可以吗', 'O']],
#   [['患者：有点', 'O'], ['咳嗽', 'Symptom']],
#   [['医生：', 'O'], ['拉肚子', 'Symptom'], ['没完全好不建议吃', 'O']],
#   [['患者：今天吃了两次，有影响吗', 'O']],
#   [['医生：会有影响的', 'O']],
#   [['患者：哦哦，那', 'O'], ['咳嗽', 'Symptom'], ['怎么办', 'O']],
#   [['医生：', 'O'], ['糖浆', 'Drug_Category'], ['可以吃一点', 'O']],
#   [['患者：那是药吗', 'O']],
#   [['医生：恩', 'O']],
#   [['医生：', 'O'], ['止咳糖浆', 'Drug']],
#   [['患者：那有副作用吗', 'O']],
#   [['医生：比较小的', 'O']],
#   [['医生：选择1岁以内儿童可以吃的', 'O']],
#   [['患者：好的，谢谢', 'O']],
#   [['医生：还有其他问题吗', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：您好，现在主要症状是什么？', 'O']],
#   [['患者：', 'O'], ['流鼻涕', 'Symptom'], ['，', 'O'], ['咳嗽', 'Symptom']],
#   [['医生：孩子还在', 'O'], ['发烧', 'Symptom'], ['不？', 'O']],
#   [['患者：不停的', 'O'], ['咳', 'Symptom']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'],
#    ['咳', 'Symptom'],
#    ['的出来', 'O'],
#    ['痰', 'Symptom'],
#    ['没有', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['几天了', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['频率较前有加重没有', 'O']],
#   [['患者：昨天一点点，严重了', 'O']],
#   [['医生：您们宝宝，有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻涕', 'Symptom'],
#    ['的症状，这种属于', 'O'],
#    ['呼吸道感染', 'Symptom'],
#    ['的表现', 'O']],
#   [['医生：可能是', 'O'], ['支气管炎', 'Symptom']],
#   [['患者：用什么药好些？', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['的时候', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['血常规', 'Medical_Examination'],
#    ['没有', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：多长时间没有', 'O'], ['发烧', 'Symptom'], ['了', 'O']],
#   [['患者：如果有', 'O'], ['发烧', 'Symptom'], ['可能是什么病症？', 'O']],
#   [['医生：还是支持', 'O'], ['支气管炎', 'Symptom']],
#   [['患者：今天', 'O']],
#   [['医生：这种情况', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['比较严重，我还是建议去找医生', 'O'],
#    ['听诊', 'Medical_Examination'],
#    ['一下肺部', 'O']],
#   [['患者：哦', 'O']],
#   [['医生：然后根据肺部情况觉定是否照片还是口服药物和', 'O'], ['雾化', 'Operation'], ['止咳治疗', 'O']],
#   [['患者：要是', 'O'], ['支气管炎', 'Symptom'], ['用什么药好？', 'O']],
#   [['医生：我们不针对个人提供处方药物，因为网络局限性', 'O']],
#   [['医生：针对', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['可以选择', 'O'],
#    ['止咳化痰药物', 'Drug_Category'],
#    ['，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['频繁可以选择', 'O'],
#    ['雾化', 'Operation'],
#    ['治疗', 'O']],
#   [['患者：好的，谢谢', 'O']],
#   [['医生：同时如果有', 'O'],
#    ['发烧', 'Symptom'],
#    ['，还要', 'O'],
#    ['查', 'Medical_Examination'],
#    ['血常规', 'Medical_Examination'],
#    ['看到底是', 'O'],
#    ['病毒感染', 'Symptom'],
#    ['还是', 'O'],
#    ['细菌感染', 'Symptom'],
#    ['导致', 'O']],
#   [['医生：然后根据结果指导用药', 'O']],
#   [['患者：嗯', 'O']],
#   [['医生：请问，您还有什么问题需要咨询？', 'O']],
#   [['患者：没有了，谢谢', 'O']],
#   [['医生：您好，很高兴为您服务，为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合，谢谢您。', 'O']],
#   [['医生：您好，这是腋温吗？', 'O']],
#   [['患者：恩，是的', 'O']],
#   [['医生：孩子有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['呕吐', 'Symptom'],
#    ['腹泻', 'Symptom'],
#    ['等症状吗？', 'O']],
#   [['患者：暂时没有', 'O']],
#   [['医生：有点', 'O'], ['低热', 'Symptom'], ['，但不高的，您可以先给他物理降温，多饮食，洗个温水澡的哦', 'O']],
#   [['医生：应该是多饮水', 'O']],
#   [['医生：请问孩子的精神反应怎么样呢？', 'O']],
#   [['患者：恩，她今天', 'O'], ['留清鼻涕', 'Symptom']],
#   [['患者：有点', 'O'], ['感冒', 'Symptom'], ['，老说鼻子不舒服', 'O']],
#   [['医生：您可以先给他吃点预防', 'O'], ['上呼吸道感染', 'Symptom'], ['的用药的哦', 'O']],
#   [['患者：精神不是很好', 'O']],
#   [['医生：一般', 'O'],
#    ['低热', 'Symptom'],
#    ['的话，孩子的精神反应会差一些，您在关注体温，如果体温超过', 'O'],
#    ['38度5', 'Symptom'],
#    ['，需要用', 'O'],
#    ['退热药', 'Drug_Category'],
#    ['的，没有超过', 'O'],
#    ['38度', 'Symptom'],
#    ['，您可以给他洗澡，物理降温的。', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：孩子还是有感染的，但', 'O'],
#    ['感冒', 'Symptom'],
#    ['初期一般以病毒感染为主，所以您的用药先以', 'O'],
#    ['抗病毒', 'Drug_Category'],
#    ['清热解毒', 'Drug_Category'],
#    ['类的用药为主的。', 'O']],
#   [['患者：这个可以吗？', 'O']],
#   [['医生：可以的。', 'O']],
#   [['患者：恩，好的，非常感谢', 'O']],
#   [['医生：一定要多喝水哦，如果', 'O'],
#    ['发热', 'Symptom'],
#    ['越来越高，尽量去附近医院就诊一下，明确感染病灶和感染的性质的。', 'O']],
#   [['患者：恩，好的', 'O']],
#   [['医生：好的，不客气的。', 'O']],
#   [['医生：你好', 'O']],
#   [['患者：宝宝', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['，还', 'O'],
#    ['发烧', 'Symptom'],
#    ['怎么办啊', 'O']],
#   [['医生：这孩子现在精神状态怎么样？尿量怎么样', 'O']],
#   [['医生：超过', 'O'],
#    ['38.5', 'Symptom'],
#    ['度需要给孩子口服', 'O'],
#    ['退热药物', 'Drug_Category']],
#   [['患者：', 'O'], ['尿比平常少', 'Symptom']],
#   [['患者：', 'O'], ['退烧药', 'Drug_Category'], ['吃了', 'O']],
#   [['医生：这样的孩子需要多喝水的，避免', 'O'], ['脱水', 'Symptom']],
#   [['医生：根据你所描述的情况，这个孩子需要考虑', 'O'], ['病毒性肠炎', 'Symptom'], ['！', 'O']],
#   [['医生：这孩子出现', 'O'],
#    ['发热', 'Symptom'],
#    ['之前有没有受凉的情况，有没有', 'O'],
#    ['呼吸道感染', 'Symptom'],
#    ['的情况？', 'O']],
#   [['患者：孩子还在吃母乳，喝水比较少，一直在吃母乳', 'O']],
#   [['患者：前几天', 'O'],
#    ['感冒', 'Symptom'],
#    ['在医院', 'O'],
#    ['输液', 'Operation'],
#    ['7天', 'O']],
#   [['医生：这样的孩子应该多喝水的，尽可能少吃奶应该以米粉为主，如果就是想吃奶，应该是腹泻奶粉', 'O']],
#   [['医生：是不是在', 'O'],
#    ['感冒', 'Symptom'],
#    ['的后期出现', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['？', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：现在的这种情况需要继续', 'O'],
#    ['输液', 'Operation'],
#    ['治疗的！反复的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['可能会导致孩子出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况', 'O']],
#   [['患者：', 'O'],
#    ['输液', 'Operation'],
#    ['停了一天，然后就', 'O'],
#    ['拉肚子', 'Symptom'],
#    ['发烧', 'Symptom']],
#   [['医生：这孩子没有', 'O'], ['呕吐', 'Symptom'], ['的情况吧', 'O']],
#   [['患者：昨天有', 'O'], ['吐', 'Symptom']],
#   [['患者：今天没有', 'O']],
#   [['患者：她有', 'O'],
#    ['痰', 'Symptom'],
#    ['，不吃药一哭就', 'O'],
#    ['吐', 'Symptom'],
#    ['了', 'O']],
#   [['医生：那应该问题不大的', 'O']],
#   [['医生：这种情况需要让孩子多喝水的', 'O']],
#   [['患者：今天', 'O'],
#    ['痰', 'Symptom'],
#    ['没有了，还是', 'O'],
#    ['流鼻涕', 'Symptom'],
#    ['，', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚子', 'Symptom']],
#   [['医生：可以选择口服', 'O'], ['补液盐', 'Drug']],
#   [['医生：如果这个孩子刚开始有', 'O'],
#    ['呼吸道感染', 'Symptom'],
#    ['的情况，出现', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，需要注意', 'O'],
#    ['轮状病毒肠炎', 'Symptom'],
#    ['的可能', 'O']],
#   [['患者：', 'O'], ['肠炎', 'Symptom'], ['是什么症状呢', 'O']],
#   [['医生：', 'O'],
#    ['轮状病毒肠炎', 'Symptom'],
#    ['最常见的症状就是', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，', 'O'],
#    ['呕吐', 'Symptom'],
#    ['发热', 'Symptom'],
#    ['，这个大便是', 'O'],
#    ['蛋花汤样大便', 'Symptom'],
#    ['，大便当中', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['比较多，水特别的多', 'O']],
#   [['患者：', 'O'],
#    ['输液', 'Operation'],
#    ['的时候没', 'O'],
#    ['拉', 'Symptom'],
#    ['，停的那一天也没拉，是停药的第二天拉的', 'O']],
#   [['患者：我家宝宝出了', 'O'], ['呕吐', 'Symptom'], ['别的症状都有', 'O']],
#   [['医生：对呀，它有个潜伏期', 'O']],
#   [['医生：不可能每个孩子所有的症状都出现的', 'O']],
#   [['医生：这个孩子需要到医院进行', 'O'],
#    ['轮状病毒抗体', 'Medical_Examination'],
#    ['的', 'O'],
#    ['检查', 'Medical_Examination']],
#   [['患者：那必须要', 'O'], ['输液', 'Operation'], ['吗', 'O']],
#   [['患者：', 'O'], ['验血', 'Medical_Examination'], ['吗', 'O']],
#   [['医生：如果这个孩子能够喝口服', 'O'], ['补液盐', 'Drug'], ['，尿量正常，可以先口服药物试试看', 'O']],
#   [['医生：', 'O'],
#    ['轮状病毒抗体', 'Medical_Examination'],
#    ['是', 'O'],
#    ['查', 'Medical_Examination'],
#    ['大便', 'Medical_Examination'],
#    ['的', 'O']],
#   [['患者：', 'O'], ['补液盐', 'Drug'], ['是药的名字吗', 'O']],
#   [['医生：是的', 'O']],
#   [['患者：大约几天能够好', 'O']],
#   [['医生：', 'O'], ['轮状病毒肠炎', 'Symptom'], ['的病程应该在一个周左右', 'O']],
#   [['医生：高峰期为3到4天', 'O']],
#   [['患者：不', 'O'], ['输液', 'Operation'], ['，一周过后会好嘛', 'O']],
#   [['患者：还是会严重', 'O']],
#   [['医生：前提是没有出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况，一定要', 'O'],
#    ['补液', 'Operation'],
#    ['的', 'O']],
#   [['医生：因为', 'O'],
#    ['轮状病毒肠炎', 'Symptom'],
#    ['很容易出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['，会出现水', 'O'],
#    ['电解质', 'Drug_Category'],
#    ['的紊乱', 'O']],
#   [['医生：如果这个孩子出现', 'O'],
#    ['精神状态差', 'Symptom'],
#    ['，首先需要的就是', 'O'],
#    ['补液', 'Operation'],
#    ['，补足液体以后精神状态仍然不佳，需要进行', 'O'],
#    ['心电图', 'Medical_Examination'],
#    ['的', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['，以排除心肌损伤', 'O']],
#   [['患者：什么情况是孩子', 'O'], ['脱水', 'Symptom'], ['呢', 'O']],
#   [['医生：首先的表现就是', 'O'], ['尿量减少', 'Symptom']],
#   [['患者：现在吃点什么药可以缓解一下呢', 'O']],
#   [['医生：口服', 'O'], ['思密达', 'Drug'], ['胃肠黏膜', 'O']],
#   [['医生：最主要的就是多喝水', 'O']],
#   [['患者：大约一天喝多少', 'O']],
#   [['医生：这孩子体重是多少', 'O']],
#   [['患者：20斤', 'O']],
#   [['医生：每天至少喝七百毫升水', 'O']],
#   [['医生：这只是额外补充的水量', 'O']],
#   [['患者：出了', 'O'], ['补液盐', 'Drug'], ['可以吃别的嘛', 'O']],
#   [['医生：', 'O'], ['思密达', 'Drug']],
#   [['患者：', 'O'],
#    ['思密达', 'Drug'],
#    ['和', 'O'],
#    ['补液盐', 'Drug'],
#    ['吃一个就可以吗', 'O']],
#   [['医生：这两个都需要吃的', 'O']],
#   [['医生：口服', 'O'],
#    ['补液盐', 'Drug'],
#    ['是补充液体，', 'O'],
#    ['思密达', 'Drug'],
#    ['是保护胃肠黏膜的', 'O']],
#   [['患者：吃到不拉为止吗', 'O']],
#   [['医生：', 'O'], ['思密达', 'Drug'], ['最少吃3到4天', 'O']],
#   [['患者：几个小时吃一次', 'O']],
#   [['医生：孩子', 'O'],
#    ['腹泻', 'Symptom'],
#    ['的症状明显的缓解，尿量正常，可以不喝口服', 'O'],
#    ['补液盐', 'Drug']],
#   [['患者：', 'O'], ['补液盐', 'Drug'], ['一次吃多少', 'O']],
#   [['医生：', 'O'], ['思密达', 'Drug'], ['每次半包，一天三次', 'O']],
#   [['医生：口服', 'O'], ['补液盐', 'Drug'], ['今天需要喝500到700毫升', 'O']],
#   [['医生：根据这个孩子的体重每天至少需要喝700到800毫升水左右', 'O']],
#   [['医生：您好，在吗？', 'O']],
#   [['患者：在', 'O']],
#   [['医生：您好，9号那张', 'O'], ['血常规', 'Medical_Examination'], ['是最后一次查的吗？', 'O']],
#   [['患者：嗯，今天刚查的', 'O']],
#   [['医生：', 'O'], ['白细胞', 'Medical_Examination'], ['8.83那个', 'O']],
#   [['患者：嗯', 'O']],
#   [['医生：', 'O'],
#    ['白细胞', 'Medical_Examination'],
#    ['比之前有下降，但是', 'O'],
#    ['C反应蛋白', 'Medical_Examination'],
#    ['还是很高', 'O']],
#   [['医生：17多', 'O']],
#   [['医生：这个也是炎症的一项指标', 'O']],
#   [['患者：嗯，我们一直没有用药', 'O']],
#   [['医生：比之前有明显下降', 'O']],
#   [['患者：现在这种情况，是不是再观察一下', 'O']],
#   [['医生：孩子现在还有什么症状没有', 'O']],
#   [['医生：精神状态怎么样？', 'O']],
#   [['患者：偶尔', 'O'], ['小咳', 'Symptom'], ['，精神比没生病前好', 'O']],
#   [['患者：睡得比之前要多', 'O']],
#   [['医生：不', 'O'], ['发烧', 'Symptom'], ['了吧', 'O']],
#   [['患者：不', 'O'], ['发烧', 'Symptom']],
#   [['医生：这几天什么药都没吃吗？', 'O']],
#   [['患者：嗯，就6号检查回来，吃了一次', 'O'], ['布洛芬', 'Drug']],
#   [['医生：那说明宝宝自身抵抗力还是很好，这种情况建议注意观察孩子体温，精神状态，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['情况，如果能都稳定，就不需要再服药', 'O']],
#   [['患者：嗯，好的，谢谢', 'O']],
#   [['医生：不客气，宝宝的健康是我们医生最大的心愿', 'O']],
#   [['医生：我是全国第三的儿童医院医生，重庆医科大学附属儿童医院', 'O']],
#   [['医生：您有问题可以随时和我联系或留言，虽不能当面诊断，但是我能给您提供专业的解答和咨询，做您就医的私人顾问', 'O']],
#   [['患者：嗯！好的！这种情况需要验一下', 'O'], ['尿常规', 'Medical_Examination'], ['吗？', 'O']],
#   [['医生：孩子有泌尿道的问题吗？', 'O']],
#   [['患者：没有吧，我不懂！尿正常', 'O']],
#   [['患者：不黄', 'O']],
#   [['患者：就是', 'O'], ['发烧', 'Symptom'], ['的时候尿的很少很少', 'O']],
#   [['患者：现在基本和病前一样了', 'O']],
#   [['医生：这个跟', 'O'], ['发烧', 'Symptom'], ['时缺水有关', 'O']],
#   [['医生：只要现在尿跟之前一样，就不需要', 'O'], ['化验', 'Medical_Examination'], ['哈', 'O']],
#   [['医生：', 'O'], ['发烧', 'Symptom'], ['时要多喝水', 'O']],
#   [['患者：嗯现在的', 'O'], ['淋巴细胞', 'Medical_Examination'], ['比之前高，有影响吗？', 'O']],
#   [['医生：这个年龄段', 'O'],
#    ['淋巴细胞', 'Medical_Examination'],
#    ['百分比就是要高于', 'O'],
#    ['中性粒细胞', 'Medical_Examination'],
#    ['百分比', 'O']],
#   [['医生：属于正常的', 'O']],
#   [['患者：刚问的另一个医生让我用药', 'O']],
#   [['医生：主要孩子', 'O'], ['C反应蛋白', 'Medical_Examination'], ['高', 'O']],
#   [['医生：属于炎症指标', 'O']],
#   [['患者：问了二个都说吃药', 'O']],
#   [['患者：像这种炎症能自愈吗', 'O']],
#   [['医生：但是您说孩子体温都有几天不', 'O'],
#    ['发烧', 'Symptom'],
#    ['了，精神也可以，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['也只是偶尔', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，可以先观察一下', 'O']],
#   [['患者：嗯，体温都在', 'O'], ['37.5', 'Symptom'], ['以下', 'O']],
#   [['医生：因为之前10月6号', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['那么严重的时候您都没有用药', 'O']],
#   [['患者：精神状态就是你逗她，她会笑。之前可能就是张牙舞爪的', 'O']],
#   [['医生：现在', 'O'],
#    ['复查', 'Medical_Examination'],
#    ['比之前好很多，而且体温都稳定不', 'O'],
#    ['烧', 'Symptom'],
#    ['了', 'O']],
#   [['患者：嗯，是！那是不怕，现在反而怕复发了', 'O']],
#   [['患者：嗯！是，现在比之前睡得要多一些', 'O']],
#   [['医生：注意观察我说的那些，比如体温反复，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['加重，或者精神状态持续不好，那就再用药', 'O']],
#   [['患者：嗯！好的', 'O']],
#   [['医生：好的', 'O']],
#   [['医生：注意观察哈', 'O']],
#   [['患者：嗯，谢谢', 'O']],
#   [['医生：不客气，宝宝的健康是我们医生最大的心愿', 'O']],
#   [['医生：您有问题可以随时和我联系或留言，虽不能当面诊断，但是我能给您提供专业的解答和咨询，做您就医的私人顾问', 'O']],
#   [['医生：你好，小孩子有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['拉肚子', 'Symptom'],
#    ['等不适吗', 'O']],
#   [['患者：有', 'O'], ['鼻子不通', 'Symptom']],
#   [['医生：就', 'O'],
#    ['发烧', 'Symptom'],
#    ['鼻塞', 'Symptom'],
#    ['，无其他不是？精神状态怎样啊，现在多少度呢', 'O']],
#   [['患者：有一点', 'O'], ['咳嗽', 'Symptom'], ['不是经常，今天的屎先干后是拉的水', 'O']],
#   [['患者：', 'O'], ['嗜睡', 'Symptom']],
#   [['医生：', 'O'], ['水样便', 'Symptom'], ['几次了', 'O']],
#   [['患者：一次', 'O']],
#   [['医生：小便怎样啊', 'O']],
#   [['医生：现在多少度呢', 'O']],
#   [['患者：一般', 'O']],
#   [['患者：', 'O'], ['38', 'Symptom']],
#   [['患者：最早', 'O'],
#    ['38.7', 'Symptom'],
#    ['，洗澡后', 'O'],
#    ['37.8', 'Symptom'],
#    ['，现在刚睡时', 'O'],
#    ['38', 'Symptom']],
#   [['医生：小孩子比较小，虽然现在是', 'O'],
#    ['低烧', 'Symptom'],
#    ['，但如果', 'O'],
#    ['精神不好', 'Symptom'],
#    ['的话，我建议要到医院验个', 'O'],
#    ['血常规', 'Medical_Examination'],
#    ['，针对治疗', 'O']],
#   [['患者：不是', 'O'], ['低烧', 'Symptom'], ['吧温度有点高', 'O']],
#   [['医生：', 'O'],
#    ['38度', 'Symptom'],
#    ['还是', 'O'],
#    ['低烧', 'Symptom'],
#    ['的', 'O']],
#   [['患者：什么样的精神才算不好呢', 'O']],
#   [['患者：哦哦，就是不到', 'O'],
#    ['39度', 'Symptom'],
#    ['不算', 'O'],
#    ['高烧', 'Symptom'],
#    ['对吗', 'O']],
#   [['医生：你说现在', 'O'],
#    ['嗜睡', 'Symptom'],
#    ['就', 'O'],
#    ['精神不好', 'Symptom'],
#    ['了', 'O']],
#   [['医生：对啊', 'O']],
#   [['患者：恩恩', 'O']],
#   [['患者：那是不是明天就得去医院做个', 'O'], ['检查', 'Medical_Examination'], ['呢', 'O']],
#   [['医生：小孩子比较小，不懂表达，如果', 'O'],
#    ['精神不好', 'Symptom'],
#    ['，我建议现在去医院会安全点，如果精神可以，又是', 'O'],
#    ['低烧', 'Symptom'],
#    ['的话，明天应该也可以的', 'O']],
#   [['医生：这种情况你现在去吧', 'O']],
#   [['患者：洗澡后还玩了一个小时，不算是很不好吧', 'O']],
#   [['医生：你刚才说', 'O'], ['嗜睡', 'Symptom'], ['就是反应比较差了', 'O']],
#   [['患者：恩恩，谢谢', 'O']],
#   [['医生：如果精神还可以就注意体温，观察一下吧', 'O']],
#   [['医生：你好，考虑目前有', 'O'], ['感冒', 'Symptom'], ['，呼吸道炎症', 'O']],
#   [['患者：说的是', 'O'], ['支气管炎', 'Symptom']],
#   [['医生：嗯，可以先吃点药看看', 'O']],
#   [['患者：刚吃的是', 'O'],
#    ['孟鲁司特钠', 'Drug'],
#    ['和', 'O'],
#    ['阿莫西林', 'Drug'],
#    ['消炎的', 'O']],
#   [['医生：可以先吃吃看', 'O']],
#   [['患者：体温37', 'O']],
#   [['患者：一天吃几次？', 'O']],
#   [['医生：一天吃三次', 'O']],
#   [['患者：', 'O'], ['孟鲁司特钠', 'Drug'], ['也是吃三次吗', 'O']],
#   [['医生：一次', 'O']],
#   [['医生：晚上吃一次', 'O']],
#   [['患者：吃一片吗', 'O']],
#   [['医生：是的', 'O']],
#   [['患者：用吃点', 'O'], ['流鼻涕', 'Symptom'], ['的吗', 'O']],
#   [['医生：可以吃点', 'O'], ['小儿氨酚黄那敏颗粒', 'Drug']],
#   [['患者：', 'O'], ['阿莫西林', 'Drug'], ['消炎的一天三次，中间间隔多长时间', 'O']],
#   [['医生：间隔4小时', 'O']],
#   [['患者：体温37c正常吗', 'O']],
#   [['医生：正常', 'O']],
#   [['患者：谢谢您医生', 'O']],
#   [['医生：好的，别客气，再见', 'O']],
#   [['患者：', 'O'], ['孟鲁司特', 'Drug'], ['只能晚上吃吗，那白天需要吃什么', 'O']],
#   [['医生：晚上睡前吃，就可以', 'O']],
#   [['患者：白天只需要吃消炎的吗，', 'O']],
#   [['医生：是的', 'O']],
#   [['患者：谢谢，', 'O']],
#   [['医生：你好！', 'O']],
#   [['患者：您好？医生', 'O']],
#   [['医生：孩子多大了？', 'O']],
#   [['患者：一岁半了', 'O']],
#   [['医生：', 'O'], ['感冒', 'Symptom'], ['几天了？', 'O']],
#   [['患者：三天了', 'O']],
#   [['医生：', 'O'], ['发烧', 'Symptom'], ['吗？', 'O']],
#   [['患者：夜里', 'O'], ['低烧', 'Symptom']],
#   [['患者：白天不', 'O'], ['发烧', 'Symptom']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['严重是吗？', 'O']],
#   [['患者：第一天偶尔', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，可一天比一天多了，夜里一点都不', 'O'],
#    ['咳', 'Symptom'],
#    ['，白天', 'O'],
#    ['咳嗽', 'Symptom']],
#   [['医生：去医院', 'O'], ['检查', 'Medical_Examination'], ['过吗？', 'O']],
#   [['患者：不是特别严重', 'O']],
#   [['患者：没去过', 'O']],
#   [['医生：吃药几天啦', 'O']],
#   [['患者：可是我听一下肺里有点声音', 'O']],
#   [['患者：今天第三天了', 'O']],
#   [['医生：病情不见好转是吗？', 'O']],
#   [['患者：嗯', 'O']],
#   [['患者：', 'O'],
#    ['感冒', 'Symptom'],
#    ['好了点，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['严重了', 'O']],
#   [['医生：根据你说的情况，孩子还是有呼吸道的感染。', 'O']],
#   [['患者：那怎么办？', 'O']],
#   [['医生：吃药不见好转，而且', 'O'], ['咳嗽', 'Symptom'], ['加重。', 'O']],
#   [['医生：建议你去医院', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['一下，', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['血常规', 'Medical_Examination'],
#    ['拍', 'O'],
#    ['胸片', 'Medical_Examination'],
#    ['，看是否有', 'O'],
#    ['肺炎', 'Symptom'],
#    ['和', 'O'],
#    ['气管炎', 'Symptom'],
#    ['。', 'O']],
#   [['患者：我前面给他吃的', 'O'],
#    ['肺宁颗粒', 'Drug'],
#    ['，', 'O'],
#    ['护彤', 'Drug'],
#    ['，', 'O'],
#    ['再林', 'Drug']],
#   [['医生：药物是可以的', 'O']],
#   [['患者：哦，吃药不行吗？', 'O']],
#   [['医生：如果是单纯的', 'O'], ['感冒', 'Symptom'], ['吃药以后，能够减轻症状。', 'O']],
#   [['医生：如果有', 'O'],
#    ['气管炎', 'Symptom'],
#    ['和', 'O'],
#    ['肺炎', 'Symptom'],
# ...
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'I-Symptom', 'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'I-Symptom', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug_Category',
#    'I-Drug_Category',
#    'I-Drug_Category',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug_Category',
#    'I-Drug_Category',
#    'I-Drug_Category'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ...])

# %%
a = [[['医生：你好我是您的接诊医生', 'O']],
  [['医生：宝贝最近吃奶量可以吗？下降了吗', 'O']],
  [['患者：没有，也没怎么', 'O'], ['哭闹', 'Symptom']]]
del a[-1][-1][0]

a
# Out:
# [[['医生：你好我是您的接诊医生', 'O']],
#  [['医生：宝贝最近吃奶量可以吗？下降了吗', 'O']],
#  [['患者：没有，也没怎么', 'O'], ['Symptom']]]

# %%
d
# Out:
# ([[['医生：你好我是您的接诊医生', 'O']],
#   [['医生：宝贝最近吃奶量可以吗？下降了吗', 'O']],
#   [['患者：没有，也没怎么', 'O'], ['哭闹', 'Symptom']],
#   [['医生：宝妈有没有吃生冷辛辣刺激食物油腻食物来吗？', 'O']],
#   [['医生：宝贝奶粉的话最近换过牌子吗？', 'O']],
#   [['医生：宝贝肚子着凉来吗？', 'O']],
#   [['患者：喝茶油腻也少，菜吃很多', 'O']],
#   [['医生：嗯嗯，宝妈饮食一定注意，生冷辛辣刺激食物不能吃油腻食物不能吃，特别油腻食物的奥，清淡饮食为主，这个时候宝贝胃肠功能可能会有影响，能吃多少吃多少别强喂的奥！',
#     'O']],
#   [['医生：宝贝最近有没有', 'O'], ['呕吐', 'Symptom'], ['症状呢？', 'O']],
#   [['患者：', 'O'], ['呕吐', 'Symptom'], ['，有时会', 'O'], ['，不多', 'O']],
#   [['医生：嗯嗯，如果那种漾奶，每次量很少的话就问题不大，这个时候小婴儿胃处于水平位，所以很容易漾奶的奥，看好宝贝别呛到了就可以', 'O']],
#   [['医生：宝贝如果', 'O'],
#    ['呕吐', 'Symptom'],
#    ['量非常大的话就要给宝贝空肚子的奥，至少2小时不要喝水不要吃奶的', 'O']],
#   [['医生：宝贝', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['到今天为止总共第几天了呢', 'O']],
#   [['患者：现在不敢喂多，但吃不饱宝宝又会闹，就90毫升，加点水这样。', 'O']],
#   [['医生：嗯嗯，这个时候您按需哺乳就可以，能喝多少喝多少别强喂就可以的', 'O']],
#   [['医生：宝贝大便的话现在一天多少次呢？', 'O']],
#   [['患者：好的好的', 'O']],
#   [['医生：宝贝到今天为止', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['总共几天了呢？', 'O']],
#   [['患者：多多少少十来次', 'O']],
#   [['医生：大便什么样子的呢？除了', 'O'],
#    ['浠水', 'Symptom'],
#    ['之外，大便颜色正常吗？有没有', 'O'],
#    ['粘液', 'Symptom'],
#    ['脓血', 'Symptom'],
#    ['之类呢？有没有未消化的', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['呢？', 'O']],
#   [['患者：', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['有', 'O'],
#    ['粘液', 'Symptom'],
#    ['有，颜色金黄', 'O']],
#   [['医生：嗯嗯，尿量可以吗？', 'O']],
#   [['患者：尿也多', 'O']],
#   [['医生：嗯嗯，目前精神状态好尿量多的话就问题不大的！', 'O']],
#   [['医生：期间看过医生吗？', 'O']],
#   [['患者：没有，精神跟往常一样，', 'O']],
#   [['医生：宝贝目前的话大便的情况主要是一个', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的表现，', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的话可能受凉或者胃肠功能弱都可能引起来', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的，治疗的原则一般就是调节胃肠功能的治疗原则的奥', 'O']],
#   [['医生：宝贝用', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['几天了呢？症状是有点好转了，对吗', 'O']],
#   [['患者：怎么调，', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['有吃这两天', 'O']],
#   [['患者：吃了三天，好点不明显', 'O']],
#   [['目前的病情又比较稳定，所以我建议可以继续给宝贝巩固点', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['调节胃肠功能', 'O']],
#   [['医生：宝妈除了注意饮食之外，多给宝贝热敷一下肚子，顺时针揉揉肚子，别着凉，换尿布之类的快点别着凉肚子，饮食能吃多少吃多少别强喂，奶粉的话能吃多少吃多少别强喂，奶粉别太凉了！',
#     'O']],
#   [['医生：吃着', 'O'],
#    ['益生', 'Drug_Category'],
#    ['益菌', 'Drug_Category'],
#    ['观察两天，大便次数大便性状不缓解或者加重及时带宝贝去儿内科就诊', 'O'],
#    ['个', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination'],
#    ['明确一下病因，需不需要调整用药，根据结果对症处理，', 'O'],
#    ['精神', 'Symptom'],
#    ['精状', 'Symptom'],
#    ['精态', 'Symptom'],
#    ['精差', 'Symptom'],
#    ['，超过8小时没尿的话就可以及时带宝贝去儿内科就诊', 'O'],
#    ['补液', 'Operation'],
#    ['对症治疗了，防止宝贝', 'O'],
#    ['脱水', 'Symptom'],
#    ['电解', 'Symptom'],
#    ['电质', 'Symptom'],
#    ['电紊', 'Symptom'],
#    ['电乱', 'Symptom'],
#    ['的奥！', 'O']],
#   [['患者：', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['一天吃多少较好，我给一天两次，一次一包会不会多了。', 'O']],
#   [['医生：目前的话不是没有效果，是好转了，因为这个会有一个过程的，不可能用上之后症状立马就消失的奥', 'O']],
#   [['医生：这个', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['的话按照正常量的话是可以的，这个根据体重和宝贝实际情况，您最好在面诊医生那里确定一下安全性的奥', 'O']],
#   [['患者：好的谢谢医生', 'O']],
#   [['医生：孩子', 'O'], ['拉肚', 'Symptom'], ['拉子', 'Symptom'], ['总共几天了呢？', 'O']],
#   [['患者：有十天了', 'O']],
#   [['医生：孩子大便颜色呢？', 'O'],
#    ['浠水', 'Symptom'],
#    ['浠便', 'Symptom'],
#    ['吗？大便有未消化的', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['吗？', 'O']],
#   [['医生：十几天大便次数缓解了吗？', 'O']],
#   [['患者：没有', 'O'], ['奶瓣', 'Symptom']],
#   [['医生：孩子精神状态怎么样呢？', 'O']],
#   [['患者：缓解一点儿了，', 'O']],
#   [['医生：期间看过几次医生呢？', 'O']],
#   [['患者：孩子的精神状态很好，就是他，十天了已经，前几天一直是三四次，这两天是两三次，我们给吃', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['吃了有五天，', 'O']],
#   [['患者：是不是特别严重所以还没有去看过医生，', 'O']],
#   [['患者：（空）', 'O']],
#   [['患者：孩子大便是这个样子', 'O']],
#   [['医生：孩子这个目前的症状主要是', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的表现，主要是由于着凉，饮食不当等因素引起来的，治疗原则主要是调节胃肠功能的治疗原则', 'O']],
#   [['患者：不是', 'O'], ['肠炎', 'Symptom'], ['吗', 'O']],
#   [['患者：吃什么药昵，医生', 'O']],
#   [['医生：孩子', 'O'],
#    ['肠炎', 'Symptom'],
#    ['确诊的话得', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination'],
#    ['才能确定的', 'O']],
#   [['患者：吃', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['也没有好转', 'O']],
#   [['医生：孩子现在大便看着是有', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的表现的', 'O']],
#   [['患者：那我们有什么注意的吗', 'O']],
#   [['患者：需要吃些什么药能缓解', 'O']],
#   [['医生：孩子', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['时间比较长了，大便次数有所缓解了，大便次数恢复点了，胃肠功能没有完全恢复，精神状态还是可以的，用着', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['调节胃肠功能效果不好', 'O']],
#   [['患者：是的亲，用', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['不是太有效', 'O']],
#   [['医生：孩子现在精神状态好，病情还是比较稳定的，孩子', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['时间长，用', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['缓解不明显，胃肠功能修复比较慢，我建议带着孩子去儿内科就诊给孩子', 'O'],
#    ['个', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination'],
#    ['，看一下大便的情况，根据结果对症治疗，需不需要调整用药', 'O']],
#   [['医生：这样我们用药也是比较明确，指导我们用药，用药比较安全', 'O']],
#   [['患者：现在医院都放假呀，我带着孩子大便去行吗？不用带孩子吧', 'O']],
#   [['医生：孩子吃饭注意饮食，清淡饮食为主，别吃凉的东西，多喝点温水，肚子别着凉，多热敷一下肚子，揉揉肚子', 'O']],
#   [['患者：现在只吃奶粉', 'O']],
#   [['医生：最好带着孩子吧，医院没有放假的，都是24小时值班的！主要是时间比较长了，胃肠功能修复不好，', 'O'],
#    ['个', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination'],
#    ['明确一下病因，根据结果对症处理', 'O']],
#   [['医生：奶粉别吃凉的，吃奶别吞进去空气', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：孩子一定多喝点温水，可以在水里少放点盐，防止', 'O'],
#    ['电解', 'Symptom'],
#    ['电质', 'Symptom'],
#    ['电紊', 'Symptom'],
#    ['电乱', 'Symptom']],
#   [['患者：好的', 'O']],
#   [['医生：孩子如果胃肠功能有影响别强喂奶粉！', 'O']],
#   [['患者：好的，大夫', 'O']],
#   [['医生：如您对我的解答满意，之后您或家人若有相关问题，欢迎再次找我咨询，我会努力为您解答，谢谢！', 'O']],
#   [['患者：谢谢', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：你好孩子', 'O'], ['咳嗽', 'Symptom'], ['多长时间了', 'O']],
#   [['患者：有四五天了', 'O']],
#   [['医生：有', 'O'], ['发热', 'Symptom'], ['吗', 'O']],
#   [['患者：前几天不厉害', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：昨天晚上', 'O'], ['的厉害，一', 'O'], ['起来就停不下来', 'O']],
#   [['医生：有做过什么检查吗', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：孩子小时候', 'O'],
#    ['湿疹', 'Symptom'],
#    ['重不重平时易', 'O'],
#    ['过敏', 'Symptom'],
#    ['吗', 'O']],
#   [['患者：', 'O'], ['过一阵睡觉了就没事了', 'O']],
#   [['患者：不', 'O'], ['过敏', 'Symptom'], ['啊', 'O']],
#   [['医生：孩子经常', 'O'], ['咳嗽', 'Symptom'], ['吗', 'O']],
#   [['患者：不是', 'O']],
#   [['医生：如果只是这一次出现这种情况的话最好带孩子去', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['一下，让医生', 'O'],
#    ['一下', 'O'],
#    ['肺部', 'Medical_Examination'],
#    ['有没有问题，另外', 'O'],
#    ['下', 'O'],
#    ['支原', 'Medical_Examination'],
#    ['支体', 'Medical_Examination'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination']],
#   [['患者：嗯', 'O']],
#   [['患者：和吃东西有管吗', 'O']],
#   [['医生：给孩子吃什么东西了', 'O']],
#   [['患者：前两天吃了药，有好转，', 'O']],
#   [['患者：苹果，梨，还有西瓜，还有肉', 'O']],
#   [['医生：这些东西与', 'O'], ['咳嗽', 'Symptom'], ['应该问题不大的', 'O']],
#   [['医生：孩子前一段时间吃什么药了吃了多长时间', 'O']],
#   [['患者：吃的', 'O'],
#    ['浦地', 'Drug'],
#    ['浦蓝', 'Drug'],
#    ['浦消', 'Drug'],
#    ['浦炎', 'Drug'],
#    ['浦口', 'Drug'],
#    ['浦服', 'Drug'],
#    ['浦液', 'Drug'],
#    ['和', 'O'],
#    ['咳嗽', 'Drug_Category'],
#    ['咳药', 'Drug_Category']],
#   [['患者：吃了三天', 'O']],
#   [['医生：目前这种情况可以再给他吃几天药物然后让孩子勤喝水观察一下今晚如果', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['还严重的话要看医生', 'O']],
#   [['患者：嗯嗯好的，吃什么药好', 'O']],
#   [['医生：前几天你吃', 'O'],
#    ['蒲地', 'Drug'],
#    ['蒲蓝', 'Drug'],
#    ['和', 'O'],
#    ['止咳', 'Drug_Category'],
#    ['止药', 'Drug_Category'],
#    ['有效果可以接着吃两天的', 'O']],
#   [['医生：至于', 'O'],
#    ['消炎', 'Drug_Category'],
#    ['消药', 'Drug_Category'],
#    ['类的要根据', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['决定的', 'O']],
#   [['患者：嗯嗯好的', 'O']],
#   [['患者：吃什么饭好呢', 'O']],
#   [['医生：平时正常饮食就可以清淡易消化的', 'O']],
#   [['医生：不要吃的过多过杂', 'O']],
#   [['患者：嗯', 'O']],
#   [['医生：还有其他问题吗没有的话我关了', 'O']],
#   [['患者：吃鸡蛋行吗', 'O']],
#   [['医生：没有', 'O'], ['过敏', 'Symptom'], ['可以的', 'O']],
#   [['患者：嗯好的谢谢', 'O']],
#   [['医生：你好，目前都在什么医院治疗，还是私人诊所', 'O']],
#   [['患者：私人的', 'O']],
#   [['医生：是吧，一般正规医院，用', 'O'], ['灌肠', 'Operation'], ['治疗方式少', 'O']],
#   [['医生：目前治疗效果怎样，有效吗', 'O']],
#   [['患者：我家孩子每次有炎症都', 'O'],
#    ['肚子', 'Symptom'],
#    ['肚疼', 'Symptom'],
#    ['，腹腔淋巴肿大', 'O']],
#   [['医生：做过', 'O'],
#    ['腹部', 'Medical_Examination'],
#    ['腹彩', 'Medical_Examination'],
#    ['腹超', 'Medical_Examination'],
#    ['吗，有', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['单的话，帮你看看', 'O']],
#   [['患者：效果不错，一般两天就好了，但这次一天两次大便，', 'O']],
#   [['患者：没有。', 'O']],
#   [['患者：那还是去大医院查查？', 'O']],
#   [['医生：有效果就好，你目前有哪方面疑问', 'O']],
#   [['患者：会不会灌坏了，把孩子', 'O']],
#   [['患者：网上总说很多负面', 'O']],
#   [['患者：吓人', 'O']],
#   [['医生：多次的', 'O'], ['灌肠', 'Operation'], ['，会对肠黏膜造成损伤，正规医院都不用这个治疗手段', 'O']],
#   [['患者：我家孩子免疫力低', 'O']],
#   [['患者：每次', 'O'], ['打针', 'Operation'], ['七天以上', 'O']],
#   [['医生：建议正规公立医院诊治，可以吃点', 'O'],
#    ['增强', 'Drug_Category'],
#    ['增抵', 'Drug_Category'],
#    ['增抗', 'Drug_Category'],
#    ['增力', 'Drug_Category'],
#    ['药物', 'O']],
#   [['患者：越打越没抵抗力', 'O']],
#   [['患者：孩子没脾', 'O']],
#   [['医生：不一定非得', 'O'],
#    ['打针', 'Operation'],
#    ['，一些轻症的', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['，可以口服药', 'O']],
#   [['医生：没脾脏吗', 'O']],
#   [['患者：药吃过很多增强', 'O']],
#   [['患者：对，没脾脏', 'O']],
#   [['医生：怎么没有呢，切掉了吗', 'O']],
#   [['患者：对，', 'O']],
#   [['患者：破裂', 'O']],
#   [['医生：呃，脾破裂很危险，那样是会影响一些抵抗力的', 'O']],
#   [['患者：哎，不然不会选', 'O'], ['灌肠', 'Operation']],
#   [['医生：那样子，主要还在日常预防少生病', 'O']],
#   [['医生：也不用吃药', 'O'], ['打针', 'Operation']],
#   [['患者：去年在医院吃药，也是元旦前，', 'O'],
#    ['发烧', 'Symptom'],
#    ['三十', 'Symptom'],
#    ['三八', 'Symptom'],
#    ['三度', 'Symptom'],
#    ['就', 'O'],
#    ['了，', 'O'],
#    ['血项', 'Medical_Examination'],
#    ['三万。后来打了半个月针', 'O']],
#   [['医生：感染太重了', 'O']],
#   [['医生：很少见这么高', 'O'], ['血象', 'Medical_Examination']],
#   [['患者：今天灌两次，明天一天就能好，没什么问题吧', 'O']],
#   [['患者：害怕灌坏', 'O']],
#   [['医生：嗯，不要', 'O'], ['灌肠', 'Operation'], ['太多次', 'O']],
#   [['患者：是的我们也很小心', 'O']],
#   [['医生：一是对肠黏膜损伤，二是不知道用的哪些药', 'O']],
#   [['医生：诊所用药不太正规', 'O']],
#   [['患者：那个老大夫药很好用，好多人，各个地方的，离我们很远。挣很多钱呵呵', 'O']],
#   [['患者：', 'O'],
#    ['注射', 'Operation'],
#    ['抗生', 'Drug_Category'],
#    ['抗素', 'Drug_Category'],
#    ['不也杀', 'O'],
#    ['白细', 'Medical_Examination'],
#    ['白胞', 'Medical_Examination'],
#    ['吗', 'O']],
#   [['医生：是的，', 'O'],
#    ['抗生', 'Drug_Category'],
#    ['抗素', 'Drug_Category'],
#    ['会降', 'O'],
#    ['白细', 'Medical_Examination'],
#    ['白胞', 'Medical_Examination']],
#   [['患者：所以啊。', 'O'], ['灌肠', 'Operation'], ['真有致命的吗', 'O']],
#   [['医生：药物剂量掌握不好，是有危险的', 'O']],
#   [['患者：知道了，谢谢。', 'O']],
#   [['医生：好的，别客气，还有别的问题吗', 'O']],
#   [['患者：没了，呵呵', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：我是您的接诊医生', 'O']],
#   [['患者：您好', 'O']],
#   [['医生：宝贝主要是什么饮食呢？', 'O']],
#   [['患者：全母乳喂养', 'O']],
#   [['医生：最近吃奶量可以吗？有没有下降呢', 'O']],
#   [['患者：目前还没有正式添加辅食', 'O']],
#   [['医生：宝贝吃奶呛奶吗', 'O']],
#   [['患者：奶量和睡眠都正常', 'O']],
#   [['患者：不呛奶', 'O']],
#   [['医生：宝贝最近家里有人', 'O'], ['感冒', 'Symptom'], ['吗？', 'O']],
#   [['患者：爸爸感冒了', 'O']],
#   [['患者：没有特意隔离', 'O']],
#   [['医生：最近如果有人感冒的话带好口罩，避免交叉感染的', 'O']],
#   [['医生：宝贝总共', 'O'], ['咳嗽', 'Symptom'], ['几天了呢', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['一天能', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['几阵呢', 'O']],
#   [['患者：3月16号六个月', 'O'],
#    ['验血', 'Medical_Examination'],
#    ['，白血球有点高，过了两天有偶尔的', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['现在', 'O'],
#    ['痰量', 'Symptom'],
#    ['最近多了吗', 'O']],
#   [['患者：不是白血球高是', 'O'],
#    ['白细', 'Medical_Examination'],
#    ['白胞', 'Medical_Examination'],
#    ['高', 'O']],
#   [['患者：值是10.9', 'O']],
#   [['医生：时间太长了，这个结果没什么意义了', 'O']],
#   [['医生：', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['是一个过程，宝贝上', 'O'],
#    ['后', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状比较厉害，并不代表宝贝病情加重了，', 'O'],
#    ['液刺激的！不用担心，多给宝贝拍后背，促进', 'O'],
#    ['的排除奥！', 'O']],
#   [['患者：就是', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['的时候感觉孩子嗓子里有', 'O'],
#    ['，也没有发生憋气现象，喘气有点粗', 'O']],
#   [['医生：最近', 'O'],
#    ['痰量', 'Symptom'],
#    ['随着炎症渗出，', 'O'],
#    ['增多后刺激宝贝', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状比较明显的', 'O']],
#   [['医生：宝贝这个的话太小了所以', 'O'],
#    ['不会', 'O'],
#    ['，只能被', 'O'],
#    ['呕吐', 'Symptom'],
#    ['出去或者拉出去，所以多给宝贝拍背能把', 'O'],
#    ['呕吐', 'Symptom'],
#    ['出去也是比较好的，', 'O'],
#    ['咽下去之后胃肠功能会影响所以能吃多少吃多少别强喂奥', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：宝贝', 'O'], ['咳嗽', 'Symptom'], ['之后没有看过医生吧？', 'O']],
#   [['患者：没有，我觉得去医院太遭罪，首先得', 'O'],
#    ['验血', 'Medical_Examination'],
#    ['拍片', 'Medical_Examination'],
#    ['拍子', 'Medical_Examination']],
#   [['患者：这种情况如果没有', 'O'],
#    ['发烧', 'Symptom'],
#    ['咳嗽', 'Symptom'],
#    ['也没有加重，是不是可以让孩子自愈呢，也能提高免疫力吧？', 'O']],
#   [['医生：宝贝这个目前症状宝贝可能诊断的', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['，', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['的话这个可能由于受凉或者感染引起来的，这个治疗的原则的话主要是', 'O'],
#    ['消炎', 'Drug_Category'],
#    ['消止', 'Drug_Category'],
#    ['消咳', 'Drug_Category'],
#    ['化痰治疗的奥！', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：宝贝目前的话', 'O'],
#    ['痰量', 'Symptom'],
#    ['痰增', 'Symptom'],
#    ['痰多', 'Symptom'],
#    ['炎症渗出增多，所以我建议给宝贝先', 'O'],
#    ['个', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['胸片', 'Medical_Examination'],
#    ['，排除一下', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['，根据结果对症处理！这样能够指导我们用药，用药大体时间，用的药物也是比较对症的，宝贝恢复起来也是比较快的，利于宝贝恢复！', 'O']],
#   [['患者：需要去儿童医院吗？', 'O']],
#   [['医生：宝妈吃饭注意饮食，生冷辛辣刺激食物不能吃油腻食物不能吃，特别油腻食物容易', 'O'],
#    ['生痰', 'Symptom'],
#    ['的奥，多喝点温水，注意休息，别活动太厉害了奥，多给宝贝拍背，这个时候吃奶会有影响可能，能吃多少吃多少别强喂奥', 'O']],
#   [['医生：宝贝目前的', 'O'],
#    ['上来了', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['症状明显了，最好先做个', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['再用药，对宝贝来说也比较安全的，比较对症的奥！利于宝贝的恢复的奥', 'O']],
#   [['患者：是不是消炎累的药物都属于', 'O'],
#    ['抗生', 'Drug_Category'],
#    ['抗素', 'Drug_Category'],
#    ['呢？', 'O']],
#   [['医生：对的，看结果炎症具体大小，根据结果对症处理，这个面诊医生会根据情况给宝贝用的奥', 'O']],
#   [['患者：好的，谢谢您', 'O']],
#   [['医生：宝贝这个的', 'O'],
#    ['的目前拍上来的话就好了，这个病程总共大概需要7到10天时间，这个越小的宝贝恢复起来越慢宝贝', 'O'],
#    ['排痰', 'Symptom'],
#    ['比较慢，', 'O']],
#   [['患者：好的，明白了，非常感谢您', 'O']],
#   [['医生：所以您不用太担心了，目前的话宝贝情况还可以，做个检查明确一下病因，根据结果对症处理，再注意以上注意事项奥就可以，恢复的比较快点',
#     'O']],
#   [['患者：好，谢谢', 'O']],
#   [['医生：不客气的，祝宝贝健康', 'O']],
#   [['医生：您好', 'O']],
#   [['医生：', 'O'], ['绿色', 'Symptom'], ['绿大', 'Symptom'], ['绿便', 'Symptom']],
#   [['医生：有', 'O'], ['奶瓣', 'Symptom']],
#   [['医生：很可能是', 'O'], ['消化', 'Symptom'], ['消不', 'Symptom'], ['消良', 'Symptom']],
#   [['患者：拉丝状这么多', 'O']],
#   [['医生：', 'O'], ['粘液', 'Symptom'], ['多', 'O']],
#   [['医生：最近有没有受凉？', 'O'], ['感冒', 'Symptom'], ['？', 'O']],
#   [['患者：对', 'O']],
#   [['患者：', 'O'], ['感冒', 'Symptom']],
#   [['患者：一直', 'O'], ['低烧', 'Symptom']],
#   [['医生：哦，很可能是', 'O'],
#    ['感冒', 'Symptom'],
#    ['引起的', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的', 'O']],
#   [['医生：', 'O'], ['感冒', 'Symptom'], ['可以引起胃肠道功能低下', 'O']],
#   [['患者：那是不是辅食都不能添加了', 'O']],
#   [['医生：消化液分泌减少', 'O']],
#   [['患者：因为刚添加辅食的', 'O']],
#   [['医生：辅食先停下', 'O']],
#   [['医生：可以吃', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['来调节肠道', 'O']],
#   [['医生：治疗', 'O'], ['消化', 'Symptom'], ['消不', 'Symptom'], ['消良', 'Symptom']],
#   [['医生：每次一包一天2次', 'O']],
#   [['患者：本来母乳的，我', 'O'],
#    ['乳腺', 'Symptom'],
#    ['乳炎', 'Symptom'],
#    ['发炎了，不能喂，开始给宝宝吃奶粉也有关系吗', 'O']],
#   [['医生：有关系。奶粉不好消化', 'O']],
#   [['医生：适应需要过程', 'O']],
#   [['患者：大便这样的还要多久才能正常啊', 'O']],
#   [['患者：看着有点吓人啊', 'O']],
#   [['医生：等', 'O'], ['感冒', 'Symptom'], ['好利索后过几天就好的', 'O']],
#   [['医生：宝宝食欲可以吗？', 'O']],
#   [['患者：还行，不过比之前减少很多', 'O']],
#   [['患者：不过也不算差', 'O']],
#   [['医生：哦，目前不算严重。可以吃药看看。假如出现精神食欲差，就有必要去医院儿科看看的', 'O']],
#   [['医生：不在了吗？', 'O']],
#   [['医生：有问题留言', 'O']],
#   [['医生：你好！', 'O']],
#   [['患者：两个多月', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['一吃就', 'O'],
#    ['怎么办、两三天没吃东西了也没有拉大便', 'O']],
#   [['医生：', 'O'], ['发烧', 'Symptom'], ['吗？', 'O']],
#   [['患者：不', 'O'], ['发烧', 'Symptom'], ['就是有点小', 'O'], ['感冒', 'Symptom']],
#   [['医生：每次都', 'O'], ['出来吗？', 'O']],
#   [['患者：吃不到两分钟都', 'O'], ['出来了', 'O']],
#   [['医生：有', 'O'], ['咳嗽', 'Symptom'], ['吗？', 'O']],
#   [['患者：有时候', 'O']],
#   [['患者：很少', 'O']],
#   [['医生：一点儿奶也吃不了吗？', 'O']],
#   [['患者：吃但是一会都', 'O'], ['出来了', 'O']],
#   [['医生：', 'O'], ['肚子', 'Symptom'], ['肚涨', 'Symptom'], ['吗？', 'O']],
#   [['患者：应该没有', 'O']],
#   [['医生：大便什么样？', 'O']],
#   [['患者：前几天拉的有点儿', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['、这几天都都没拉呢', 'O']],
#   [['医生：还是有精神吗？', 'O'], ['哭闹', 'Symptom'], ['吧。', 'O']],
#   [['患者：拉的像', 'O'], ['蛋花', 'Symptom'], ['一样', 'O']],
#   [['医生：孩子有精神吧，是不是', 'O'], ['哭闹', 'Symptom'], ['。', 'O']],
#   [['患者：有精神、就是晚上要抱、放床上就哭、白天就睡觉', 'O']],
#   [['医生：去医院', 'O'], ['检查', 'Medical_Examination'], ['过吗？', 'O']],
#   [['患者：去了说是', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['有点小', 'O'],
#    ['感冒', 'Symptom']],
#   [['医生：吃过药了吗？', 'O']],
#   [['患者：开了', 'O'],
#    ['醒脾', 'Drug'],
#    ['醒养', 'Drug'],
#    ['醒儿', 'Drug'],
#    ['醒颗', 'Drug'],
#    ['醒粒', 'Drug']],
#   [['医生：吃了几天了，效果怎么样。', 'O']],
#   [['患者：', 'O'],
#    ['儿童', 'Drug'],
#    ['儿回', 'Drug'],
#    ['儿春', 'Drug'],
#    ['儿颗', 'Drug'],
#    ['儿粒', 'Drug']],
#   [['医生：', 'O'], ['呕吐', 'Symptom'], ['减轻吧', 'O']],
#   [['患者：从昨天到今天好像没什么效果', 'O']],
#   [['患者：还是一样的', 'O']],
#   [['医生：根据你说的情况，我分析孩子还是有', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的。', 'O']],
#   [['医生：一共吃了几天药啦', 'O']],
#   [['患者：帖', 'O'],
#    ['止吐', 'Drug_Category'],
#    ['止帖', 'Drug_Category'],
#    ['也不管用', 'O']],
#   [['患者：今天两天', 'O']],
#   [['医生：孩子尿量少吗？', 'O']],
#   [['患者：不少', 'O']],
#   [['医生：可以适当的调整一下药物。', 'O']],
#   [['患者：几天都没拉大便了', 'O']],
#   [['医生：吃上', 'O'],
#    ['吗咪', 'Drug'],
#    ['吗爱', 'Drug'],
#    ['助消', 'Drug_Category'],
#    ['助化', 'Drug_Category'],
#    ['的', 'O']],
#   [['患者：现在也有在吃', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug'], ['的', 'O']],
#   [['医生：孩子小抵抗力差，如果', 'O'],
#    ['呕吐', 'Symptom'],
#    ['不止，会引起', 'O'],
#    ['脱水', 'Symptom'],
#    ['的。', 'O']],
#   [['患者：那怎么办呢', 'O']],
#   [['医生：如果是比较快还是静脉', 'O'], ['输液', 'Operation'], ['。', 'O']],
#   [['医生：吃药不见好转，孩子小会引起', 'O'], ['脱水', 'Symptom'], ['酸中毒。', 'O']],
#   [['医生：静脉', 'O'], ['输液', 'Operation'], ['效果还是比较快的。', 'O']],
#   [['患者：昨天医院也说让', 'O'], ['输液', 'Operation'], ['家人说孩子太小了', 'O']],
#   [['患者：好吧、今天不好就只有', 'O'], ['输夜', 'Operation'], ['了', 'O']],
#   [['医生：还是', 'O'], ['呕吐', 'Symptom'], ['不止，会引起其他疾病，以免耽误病情。', 'O']],
#   [['患者：好的、谢谢', 'O']],
#   [['医生：不客气的有问题及时联系', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：您好', 'O']],
#   [['患者：你好', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：宝宝现在晚上睡觉', 'O'], ['咳嗽', 'Symptom'], ['吗', 'O']],
#   [['患者：帮我看看', 'O'], ['化验', 'Medical_Examination'], ['结果', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['不', 'O']],
#   [['患者：', 'O'], ['咳嗽', 'Symptom'], ['好多了', 'O']],
#   [['患者：就是', 'O'],
#    ['喉咙', 'Symptom'],
#    ['喉呼', 'Symptom'],
#    ['喉吸', 'Symptom'],
#    ['喉声', 'Symptom'],
#    ['大', 'O']],
#   [['医生：这个', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['问题不大', 'O']],
#   [['医生：', 'O'],
#    ['呼噜', 'Symptom'],
#    ['呼呼', 'Symptom'],
#    ['呼噜', 'Symptom'],
#    ['的吗', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：有', 'O'],
#    ['丝丝', 'Symptom'],
#    ['丝的', 'Symptom'],
#    ['丝声', 'Symptom'],
#    ['丝音', 'Symptom'],
#    ['吗', 'O']],
#   [['患者：这个', 'O'], ['化验', 'Medical_Examination'], ['结果是针对什么的', 'O']],
#   [['患者：有吧', 'O']],
#   [['医生：原来有', 'O'],
#    ['丝丝', 'Symptom'],
#    ['丝的', 'Symptom'],
#    ['丝声', 'Symptom'],
#    ['丝音', 'Symptom'],
#    ['吗', 'O']],
#   [['患者：一直都有点，好像喉咙有', 'O'], ['一样', 'O']],
#   [['医生：这个', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['主要是看那个', 'O'],
#    ['白细', 'Medical_Examination'],
#    ['白胞', 'Medical_Examination'],
#    ['的还化验别的了吗？', 'O']],
#   [['医生：', 'O'], ['胸片', 'Medical_Examination'], ['没，', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['不', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：说是', 'O'], ['气管', 'Symptom'], ['气炎', 'Symptom']],
#   [['患者：', 'O'], ['雾化', 'Operation'], ['有用吗', 'O']],
#   [['医生：现在打什么', 'O'], ['点滴', 'Operation'], ['呢', 'O']],
#   [['医生：局部', 'O'],
#    ['雾化', 'Operation'],
#    ['止咳', 'Drug_Category'],
#    ['止化', 'Drug_Category'],
#    ['止痰', 'Drug_Category'],
#    ['效果好', 'O']],
#   [['医生：副作用小', 'O']],
#   [['医生：宝宝现在怎么样了？', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：宝宝是母乳喂养吗？', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：精神吃奶好吗？', 'O']],
#   [['患者：平常一样', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：原来1天大便几次？', 'O']],
#   [['患者：今天有一次边吃边', 'O']],
#   [['患者：四次左右', 'O']],
#   [['医生：哦，', 'O']],
#   [['医生：1天增加了2次', 'O']],
#   [['医生：现在体温正常吗？', 'O']],
#   [['患者：体温正常', 'O']],
#   [['医生：嗯，宝宝', 'O'], ['肚子', 'Symptom'], ['肚胀', 'Symptom'], ['吗', 'O']],
#   [['患者：不', 'O']],
#   [['医生：哦，如果宝宝下次大便还有这种情况，建议给宝宝', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['一下', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination']],
#   [['患者：今天有两次这种情况了', 'O']],
#   [['医生：哦，', 'O']],
#   [['医生：继续观察一下，如果明天还有，就留', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['化验', 'Medical_Examination'],
#    ['一下', 'O']],
#   [['医生：1个小时之内的大便都可以', 'O'], ['化验', 'Medical_Examination'], ['的', 'O']],
#   [['患者：好的，谢谢医生', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['患者：我昨天吃了血蛤有关系吗', 'O']],
#   [['医生：考虑关系不大', 'O']],
#   [['患者：喔喔，好的', 'O']],
#   [['医生：好的，给宝宝喂奶时，注意洗干净乳头', 'O']],
#   [['医生：注意腹部保暖', 'O']],
#   [['医生：可以口服', 'O'], ['妈咪', 'Drug'], ['妈爱', 'Drug']],
#   [['患者：好的', 'O']],
#   [['医生：好，有事联系', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：祝宝宝健康快乐成长', 'O']],
#   [['医生：您好，我是您的辅诊医生，需要询问几个问题，才能更好的评估孩子情况，您还在吗？', 'O']],
#   [['医生：宝宝纯母乳喂养吗', 'O']],
#   [['患者：嗯是的', 'O']],
#   [['医生：宝宝大便什么样子', 'O']],
#   [['医生：一天拉几次', 'O']],
#   [['患者：黄色', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：宝宝', 'O'], ['肚子', 'Symptom'], ['肚胀', 'Symptom'], ['吗', 'O']],
#   [['患者：有点', 'O']],
#   [['医生：一天拉几次', 'O']],
#   [['患者：5，6次吧', 'O']],
#   [['患者：', 'O'], ['放屁', 'Symptom'], ['多', 'O']],
#   [['医生：量多吗？', 'O']],
#   [['医生：宝宝以前大便什么样子', 'O']],
#   [['患者：泡沫大便', 'O']],
#   [['患者：不多', 'O']],
#   [['医生：宝宝有', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['症状的', 'O']],
#   [['医生：母亲有没有吃不好消化的食物?', 'O']],
#   [['患者：都是稀泡沫', 'O']],
#   [['患者：只吃面和和小米粥啊', 'O']],
#   [['医生：泡沫一般是未消化的脂肪粒', 'O']],
#   [['医生：有没有吃凉的或者隔夜菜', 'O']],
#   [['患者：应该怎么办', 'O']],
#   [['医生：可以给宝贝顺时针揉一下肚子或者热敷一下，用热水袋，注意不要烫伤。', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：都是现做的饭', 'O']],
#   [['医生：喂完抱一会宝宝，拍出饱嗝，不要让宝贝吃太急，尽量右侧卧位房宝宝', 'O']],
#   [['患者：奥', 'O']],
#   [['患者：不要紧么', 'O']],
#   [['医生：吃奶后半小时按摩', 'O']],
#   [['患者：好的??', 'O']],
#   [['医生：嗯嗯', 'O']],
#   [['医生：注意饮食卫生', 'O']],
#   [['医生：喂奶前后擦拭乳头哦', 'O']],
#   [['医生：祝宝宝健康成长', 'O']],
#   [['医生：您还有疑问吗?', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：可能您在忙，稍后有疑问可以给我留言', 'O']],
#   [['医生：如果您超过五分钟不回复，系统会自动关闭对话，您还在吗？', 'O']],
#   [['医生：你好', 'O']],
#   [['患者：你好', 'O']],
#   [['医生：请问宝宝', 'O'], ['化验', 'Medical_Examination'], ['了吗？', 'O']],
#   [['患者：化验了', 'O']],
#   [['医生：方便把', 'O'], ['化验', 'Medical_Examination'], ['单拍照发过来吗？', 'O']],
#   [['患者：好', 'O']],
#   [['医生：嗯', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：孩子是有明确的', 'O'],
#    ['细菌', 'Symptom'],
#    ['细感', 'Symptom'],
#    ['细染', 'Symptom'],
#    ['，用', 'O'],
#    ['头孢', 'Drug_Category'],
#    ['是合适的，这三样药孩子以前有吃过吗？', 'O']],
#   [['患者：今天一直', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['还给吃了', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['，但没有效果', 'O']],
#   [['患者：有吃过', 'O']],
#   [['医生：昨天之前大便怎么样？', 'O']],
#   [['患者：昨天有点', 'O'], ['拉肚', 'Symptom'], ['拉子', 'Symptom'], ['没今天严重', 'O']],
#   [['医生：哦，大便有化验吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：今天', 'O'], ['了几次？', 'O']],
#   [['患者：有十次左右', 'O']],
#   [['医生：有大便的照片吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'],
#    ['大便', 'Symptom'],
#    ['大很', 'Symptom'],
#    ['大稀', 'Symptom'],
#    ['吗？什么颜色？', 'O']],
#   [['患者：大便土黄色，', 'O'], ['浠水', 'Symptom']],
#   [['医生：', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['你具体是怎么喂的？', 'O']],
#   [['患者：一次三袋，冲水喝', 'O']],
#   [['医生：孩子今天精神、食欲怎么样？', 'O']],
#   [['患者：中午喝了一次，晚上饭后喝了一次', 'O']],
#   [['患者：食欲还可以', 'O']],
#   [['医生：', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['是需要在饭前空腹时吃才有止泻效果的。', 'O']],
#   [['患者：精神挺好的', 'O']],
#   [['患者：我都给她饭后吃了', 'O']],
#   [['医生：嗯，那是没有效果的', 'O']],
#   [['患者：那晚上还要给她吃吗', 'O']],
#   [['患者：需要吃别的药吗', 'O']],
#   [['医生：孩子在用药后出现', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，但是以前也吃过类似的药物，没有出现这种症状，不太考虑药物引起。首先需要在饭前空腹时吃', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['，同时可以口服', 'O'],
#    ['益生', 'Drug_Category'],
#    ['益菌', 'Drug_Category'],
#    ['调理。', 'O']],
#   [['患者：', 'O'], ['消食', 'Drug'], ['消片', 'Drug'], ['可以吗', 'O']],
#   [['医生：也可以的', 'O']],
#   [['医生：孩子目前的情况是考虑', 'O'],
#    ['消化', 'Symptom'],
#    ['消不', 'Symptom'],
#    ['消良', 'Symptom'],
#    ['的，在这期间饮食尽量要清淡一点，宜少食多餐，减轻胃肠道负担。', 'O']],
#   [['患者：那等下我再给她吃', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['和', 'O'],
#    ['消食', 'Drug'],
#    ['消片', 'Drug'],
#    ['吗', 'O']],
#   [['医生：好的', 'O']],
#   [['患者：好，谢谢了', 'O']],
#   [['医生：如果用药两天宝宝症状没有任何缓解，或者再次出现', 'O'], ['发热', 'Symptom'], ['，需要到医院复诊。', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：嗯', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：是今天刚开始发现的吗', 'O']],
#   [['医生：', 'O'],
#    ['咽喉', 'Symptom'],
#    ['咽有', 'Symptom'],
#    ['咽充', 'Symptom'],
#    ['咽血', 'Symptom']],
#   [['患者：昨天', 'O'],
#    ['发烧', 'Symptom'],
#    ['，但是', 'O'],
#    ['退烧', 'Drug_Category'],
#    ['退药', 'Drug_Category'],
#    ['吃了就', 'O'],
#    ['了', 'O']],
#   [['医生：除了', 'O'],
#    ['发烧', 'Symptom'],
#    ['，有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['之类其他症状吗', 'O']],
#   [['患者：昨天', 'O'],
#    ['喉咙', 'Symptom'],
#    ['喉没', 'Symptom'],
#    ['喉有', 'Symptom'],
#    ['喉充', 'Symptom'],
#    ['喉血', 'Symptom']],
#   [['患者：很少', 'O'], ['咳嗽', 'Symptom']],
#   [['医生：嗯，因为疾病是一个发展过程', 'O']],
#   [['患者：就是', 'O'],
#    ['扁桃', 'Symptom'],
#    ['扁体', 'Symptom'],
#    ['扁发', 'Symptom'],
#    ['扁炎', 'Symptom'],
#    ['还是其他什么病？', 'O']],
#   [['医生：', 'O'], ['扁桃', 'Symptom'], ['扁体', 'Symptom'], ['白色小泡', 'O']],
#   [['患者：嗯，有三四个', 'O']],
#   [['医生：有化脓点吗', 'O']],
#   [['患者：拍照不好拍到', 'O']],
#   [['患者：好像没有', 'O']],
#   [['医生：是的，看不是很大出来', 'O']],
#   [['医生：那你要注意除', 'O'],
#    ['扁桃', 'Symptom'],
#    ['扁体', 'Symptom'],
#    ['扁炎', 'Symptom'],
#    ['外另一点是，', 'O'],
#    ['疱疹', 'Symptom'],
#    ['疱性', 'Symptom'],
#    ['疱咽', 'Symptom'],
#    ['疱峡', 'Symptom'],
#    ['疱炎', 'Symptom']],
#   [['医生：建议', 'O'],
#    ['个', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['看有没有并发感染', 'O']],
#   [['患者：吃了', 'O'],
#    ['消炎', 'Drug_Category'],
#    ['消药', 'Drug_Category'],
#    ['后', 'O'],
#    ['发烧', 'Symptom'],
#    ['没有超过', 'O'],
#    ['38', 'Symptom'],
#    ['3度', 'Symptom'],
#    ['了', 'O']],
#   [['医生：吃的', 'O'], ['头孢', 'Drug_Category'], ['是吗', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：如果是化脓性', 'O'],
#    ['扁桃', 'Symptom'],
#    ['扁体', 'Symptom'],
#    ['扁炎', 'Symptom'],
#    ['是对的', 'O']],
#   [['医生：是给医生看过，开药的吗', 'O']],
#   [['患者：要是', 'O'], ['疱疹', 'Symptom'], ['那个呢', 'O']],
#   [['患者：不是，家里备的药', 'O']],
#   [['医生：如果吃', 'O'],
#    ['头孢', 'Drug_Category'],
#    ['有效果那化脓性', 'O'],
#    ['扁桃', 'Symptom'],
#    ['扁体', 'Symptom'],
#    ['扁炎', 'Symptom'],
#    ['也是比较可能', 'O']],
#   [['患者：现在就是有时还有点', 'O'],
#    ['低烧', 'Symptom'],
#    ['，', 'O'],
#    ['37', 'Symptom'],
#    ['3.', 'Symptom'],
#    ['36', 'Symptom']],
#   [['医生：', 'O'],
#    ['38', 'Symptom'],
#    ['3.', 'Symptom'],
#    ['35', 'Symptom'],
#    ['℃以下可以不用', 'O'],
#    ['退烧', 'Drug_Category'],
#    ['退药', 'Drug_Category'],
#    ['的', 'O']],
#   [['患者：没有用的', 'O']],
#   [['医生：', 'O'], ['低烧', 'Symptom'], ['话，一般也会两三天', 'O']],
#   [['医生：是的，主要是物理降温为主', 'O']],
#   [['医生：如果家里备的药吃了有效，可以先吃着观察一下', 'O']],
#   [['患者：炎症好的', 'O']],
#   [['医生：但是要按剂量来，按上面说明书', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：炎症得三四天才能消吧', 'O']],
#   [['医生：如果没有感觉好转，是建议能够去看一下', 'O']],
#   [['医生：一般三四天，如果没有好转是要去看', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：谢谢', 'O']],
#   [['医生：您好', 'O']],
#   [['患者：你好', 'O']],
#   [['患者：我家宝宝怎么回事', 'O']],
#   [['医生：怎么最近的话有末有受凉呀她这个大便带粘液你一天大便几次，', 'O']],
#   [['患者：3到4次', 'O']],
#   [['医生：我之前的话他大病一般一天几次啊，', 'O']],
#   [['患者：1到2次', 'O']],
#   [['患者：就是', 'O']],
#   [['医生：就大便次数增多这个考虑是副业，嗯要是明天的话要', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['大常', 'Medical_Examination'],
#    ['大规', 'Medical_Examination'],
#    ['，', 'O']],
#   [['患者：还有点沫沫', 'O']],
#   [['医生：那你最近的话给宝宝多吃一点白粥米汤男少喝一点然后吃一点', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['或者', 'O'],
#    ['益生', 'Drug_Category'],
#    ['益菌', 'Drug_Category'],
#    ['类的菜，', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：好几天了', 'O']],
#   [['医生：（空）', 'O']],
#   [['医生：吃好几天了如果你要出来的话最好吃腹泻奶粉就是问问棠配方奶粉，', 'O']],
#   [['患者：拉的太', 'O'], ['了', 'O']],
#   [['医生：对于因为主要考虑还拿了个病毒的话那就是那个水塘没可能又缺乏但是母乳喝一段奶粉转就是还有点疼，', 'O']],
#   [['患者：不能喝母乳了？', 'O']],
#   [['患者：可是孩子不喝奶粉', 'O']],
#   [['医生：喝母乳的话就吃点', 'O'],
#    ['乳糖', 'Drug'],
#    ['乳酶', 'Drug'],
#    ['，但是文化可能么有了这个我现在不好，', 'O']],
#   [['医生：最好是少喝奶粉然后观察一下因为了时间太长了可能有', 'O'],
#    ['乳糖', 'Drug'],
#    ['乳酶', 'Drug'],
#    ['的缺乏，', 'O']],
#   [['患者：没喝过奶粉', 'O']],
#   [['患者：一直母乳喂养', 'O']],
#   [['医生：那最好吃', 'O'], ['乳糖', 'Drug'], ['乳酶', 'Drug'], ['，就是母乳前吃', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：婴儿店里有卖吗', 'O']],
#   [['医生：有的，大的母婴店有卖的', 'O']],
#   [['患者：哦哦！谢谢', 'O']],
#   [['医生：不客气', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：您可在咨询结束后点击（首页），在首页里找到（康复记录），在康复记录里找到我然后点（再次咨询)', 'O']],
#   [['医生：祝宝宝早日康复', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：刚好你看下有没其它问题我没我的话我就结束服务了，', 'O']],
#   [['医生：如果后面还有问题的话你再给我发，再问我，', 'O']],
#   [['患者：恩，好的', 'O']],
#   [['医生：嗯嗯，祝新年快乐', 'O']],
#   [['医生：????', 'O']],
#   [['患者：新年快乐', 'O']],
#   [['医生：拜拜', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：在吗', 'O']],
#   [['医生：为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合。', 'O']],
#   [['患者：在', 'O']],
#   [['患者：您好', 'O']],
#   [['医生：宝宝病了几天了', 'O']],
#   [['患者：四天了', 'O']],
#   [['医生：宝宝', 'O'], ['咳嗽', 'Symptom'], ['是一声声还是一顿顿的', 'O']],
#   [['患者：声', 'O']],
#   [['医生：宝宝', 'O'], ['咳嗽', 'Symptom'], ['是白天严重还是夜间严重', 'O']],
#   [['患者：就昨天没有', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['咳嗽', 'Symptom'],
#    ['，今天又开始了', 'O']],
#   [['医生：有没有', 'O'], ['发热', 'Symptom'], ['？', 'O']],
#   [['患者：没有', 'O'], ['发烧', 'Symptom']],
#   [['患者：精神正常', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['有', 'O'], ['吗？', 'O']],
#   [['患者：', 'O'], ['咳嗽', 'Symptom'], ['不多', 'O']],
#   [['医生：有没有', 'O'], ['喘息', 'Symptom'], ['症状', 'O']],
#   [['患者：就是有', 'O']],
#   [['患者：说是', 'O'], ['咽炎', 'Symptom']],
#   [['医生：宝宝大便正常吗', 'O']],
#   [['患者：', 'O'],
#    ['鼻子', 'Symptom'],
#    ['鼻不', 'Symptom'],
#    ['鼻通', 'Symptom'],
#    ['鼻气', 'Symptom'],
#    ['，晚上睡觉用嘴呼吸', 'O']],
#   [['患者：正常', 'O']],
#   [['医生：饮食怎么样，宝宝精神状况如何？', 'O']],
#   [['患者：正常', 'O']],
#   [['医生：从描述症状考虑宝宝', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom']],
#   [['患者：是不是这三种药得换成别样的', 'O']],
#   [['医生：建议带宝宝到公立医院儿科找医生再听一下气管，合理', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['一下', 'O'],
#    ['胸片', 'Medical_Examination']],
#   [['医生：了解一下肺部和气管炎症情况', 'O']],
#   [['患者：嗯，还是得去医院', 'O']],
#   [['医生：如果', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['不严重可以加用', 'O'],
#    ['化痰', 'Drug_Category'],
#    ['化止', 'Drug_Category'],
#    ['化咳', 'Drug_Category'],
#    ['化药', 'Drug_Category'],
#    ['物', 'O']],
#   [['医生：从描述症状建议合理', 'O'], ['检查', 'Medical_Examination'], ['一下', 'O']],
#   [['患者：（空）', 'O']],
#   [['患者：什么药', 'O']],
#   [['医生：比如', 'O'],
#    ['肺力', 'Drug'],
#    ['肺咳', 'Drug'],
#    ['，', 'O'],
#    ['氨溴', 'Drug'],
#    ['氨特', 'Drug'],
#    ['氨罗', 'Drug']],
#   [['患者：消炎的哪？', 'O']],
#   [['医生：可以继续应用', 'O'], ['红霉', 'Drug_Category'], ['红素', 'Drug_Category']],
#   [['患者：好吧，谢谢', 'O']],
#   [['医生：不用客气，祝宝宝健康成长', 'O']],
#   [['医生：还有其他问题吗？', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['患者：再见', 'O']],
#   [['患者：嗯嗯', 'O']],
#   [['医生：如果没有其他问题，那就结束了，再见', 'O']],
#   [['医生：你好宝宝', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['有多少天呢？大便一天有多少次呢？', 'O']],
#   [['医生：有带孩子去看过医生吗？', 'O']],
#   [['患者：昨天开始的，一天十几次了，', 'O']],
#   [['医生：大便成形吗？是什么颜色的？', 'O']],
#   [['患者：没有去过医院', 'O']],
#   [['患者：没有我这小诊所', 'O']],
#   [['医生：孩子现在精神反应怎么样？体温是正常的吗？小便的量和平常相比有没有明显的减少？', 'O']],
#   [['医生：附近没有大一点的医院吗？', 'O']],
#   [['患者：没有', 'O']],
#   [['患者：小便有减少', 'O']],
#   [['医生：你好，我需要详细的掌握一些关于孩子的病情，所以才能更好的作出判断。希望你能配合。', 'O']],
#   [['医生：孩子目前精神怎么样？有测过体温吗？', 'O']],
#   [['患者：体温还好老哭', 'O']],
#   [['医生：你好，根据你的描述，孩子一天，大便次数有十多次，然后目前', 'O'],
#    ['小便', 'Symptom'],
#    ['小量', 'Symptom'],
#    ['小明', 'Symptom'],
#    ['小显', 'Symptom'],
#    ['小减', 'Symptom'],
#    ['小少', 'Symptom'],
#    ['，并且，伴', 'O'],
#    ['哭闹', 'Symptom'],
#    ['。孩子的这些表现提示目前因为反复', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，存在', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况。需要积极的做处理。给孩子喂了什么药呢？', 'O']],
#   [['医生：孩子哭的时候眼泪多不多？你可以摸一下孩子的前囟，有没有明显的凹陷？', 'O']],
#   [['医生：', 'O'],
#    ['腹泻', 'Symptom'],
#    ['它分为多种原因有可能是感染性的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，也有可能是因为喂养方式不当导致的非感染性腹泻，根据程度来划分的话，分为轻度中度和重度。会办法不同程度的，', 'O'],
#    ['脱水', 'Symptom'],
#    ['和电解质失衡。', 'O']],
#   [['患者：现在吃点', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['，还有', 'O'],
#    ['四菇', 'Drug'],
#    ['四汤', 'Drug'],
#    ['，', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug']],
#   [['医生：是去你附近诊所开的药还是自己买的？吃了药以后孩子大便。次数有明显的好转吗？', 'O']],
#   [['患者：小孩子吃的是奶粉', 'O']],
#   [['医生：奶具都严格消毒。没有？', 'O']],
#   [['患者：是去诊所问医生啦的', 'O']],
#   [['患者：有啊', 'O']],
#   [['医生：一般轻型的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['吃', 'O'],
#    ['妈咪', 'Drug'],
#    ['妈爱', 'Drug'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['孩子的大便是应该有好转的。', 'O']],
#   [['患者：今天刚刚吃的', 'O']],
#   [['不太好，有点吵闹，小便也明显减少了。考虑有', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况，需要查一下', 'O'],
#    ['电解', 'Medical_Examination'],
#    ['电质', 'Medical_Examination'],
#    ['。看是否存在', 'O'],
#    ['电解', 'Medical_Examination'],
#    ['电质', 'Medical_Examination'],
#    ['失衡。', 'O']],
#   [['医生：因为不同原因引起的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，治疗的方式还是有差异的。首先我们需要排除是否是感染性的原因。如果', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['结果没有问题的话，我们对症处理就可以了。', 'O']],
#   [['患者：大便和他拉出来的', 'O'],
#    ['鼻涕', 'Symptom'],
#    ['一样的是分开的，好像有点带不明显的', 'O'],
#    ['血丝', 'Symptom']],
#   [['医生：这种情况的话，就更需要', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['个', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['。家里去附近稍微大一点的医院，需要多长时间呀？', 'O']],
#   [['患者：要两个小时', 'O']],
#   [['医生：主要是孩子太小了，只有一个多月，反复', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，容易造成', 'O'],
#    ['脱水', 'Symptom'],
#    ['脱，', 'Symptom'],
#    ['脱水', 'Symptom'],
#    ['的话，孩子的精神就会越来越差，是比较危险的？', 'O']],
#   [['患者：是啊医生', 'O']],
#   [['医生：那个规模稍微大一点的医院是什么级别的医院呀？一般二甲以上医院晚上都可以看的有急诊。', 'O']],
#   [['医生：所以我们要比其他孩子要更引起重视', 'O']],
#   [['患者：好的我知道了谢谢你医生', 'O']],
#   [['医生：', 'O'],
#    ['腹泻', 'Symptom'],
#    ['它本身并不是十分可怕，严重的是它所造成的并发症。一定要及时处理，特别是这种小宝宝，不能拖的。', 'O']],
#   [['医生：还有，孩子', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['的', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['，尽量在一个小时之内。', 'O']],
#   [['医生：超过两个小时的', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['化验', 'Medical_Examination'],
#    ['出来是没有效的，结果也没有意义。', 'O']],
#   [['患者：好的', 'O']],
#   [['患者：谢谢', 'O']],
#   [['患者：我去看看', 'O']],
#   [['医生：你们家去医院最快也要两个小时的话，我建议你先带孩子去医院，到了医院先', 'O'],
#    ['抽血', 'Medical_Examination'],
#    ['，孩子拉大便次数有这么多，应该在医院也会拉大便。', 'O']],
#   [['医生：尽量送取新鲜的大便标本。', 'O']],
#   [['医生：因为大便放久了，它会以滋生细菌和病毒。对结果造成干扰', 'O']],
#   [['患者：好的', 'O']],
#   [['医生：好的，希望我能帮到你，早点带孩子去医院，因为孩子目前', 'O'],
#    ['精神', 'Symptom'],
#    ['精不', 'Symptom'],
#    ['精好', 'Symptom'],
#    ['，', 'O'],
#    ['脱水', 'Symptom'],
#    ['情况都比较明显', 'O']],
#   [['医生：你如果有其他的疑问可以过后找我也可以，我可以帮你分析一下，因为对', 'O'],
#    ['腹泻', 'Symptom'],
#    ['这一方面我还是比较有经验的。', 'O']],
#   [['患者：好', 'O']],
#   [['患者：谢谢了', 'O']],
#   [['医生：不用客气，如果你现在没有其她问题的话，就点击结束服务吧！我希望你从医院回来以后再次联系我，我也很关心孩子的问题。因为从我这边的话最早也只能明天联系到你。',
#     'O']],
#   [['医生：受系统的限制，我只能明天才能联系到你。', 'O']],
#   [['医生：先带孩子去医院就诊要紧。', 'O']],
#   [['医生：有任何疑问及时联系我，我看到了你的留言会及时回复你的。', 'O']],
#   [['医生：你好，孩子', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['大便', 'Medical_Examination'],
#    ['，', 'O'],
#    ['了', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['吗？', 'O']],
#   [['医生：你好', 'O']],
#   [['医生：为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合。', 'O']],
#   [['医生：在吗', 'O']],
#   [['患者：在', 'O']],
#   [['医生：宝宝', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['咳嗽', 'Symptom'],
#    ['几天了', 'O']],
#   [['患者：3天', 'O']],
#   [['医生：有没有', 'O'], ['发热', 'Symptom']],
#   [['患者：之前', 'O'], ['发烧', 'Symptom'], ['3天', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['是一声声还是一顿顿的', 'O']],
#   [['患者：', 'O'], ['发热', 'Symptom'], ['后', 'O'], ['感冒', 'Symptom']],
#   [['患者：一声一声的', 'O']],
#   [['医生：从', 'O'], ['发热', 'Symptom'], ['到现在几天了', 'O']],
#   [['患者：6天', 'O']],
#   [['医生：是夜间严重还是白天', 'O'], ['咳嗽', 'Symptom'], ['严重', 'O']],
#   [['医生：有没有', 'O'], ['喘息', 'Symptom'], ['症状', 'O']],
#   [['患者：白天', 'O']],
#   [['医生：宝宝现在应用什么药物', 'O']],
#   [['医生：还在吗', 'O']],
#   [['患者：', 'O'], ['易思', 'Drug'], ['易静', 'Drug']],
#   [['医生：还有吗', 'O']],
#   [['医生：', 'O'], ['易坦', 'Drug'], ['易静', 'Drug']],
#   [['患者：', 'O'], ['罗红', 'Drug']],
#   [['患者：', 'O'], ['小葵', 'Drug'], ['小花', 'Drug']],
#   [['医生：就这两种', 'O']],
#   [['患者：对', 'O']],
#   [['患者：3种', 'O']],
#   [['医生：有没有', 'O'], ['检查', 'Medical_Examination'], ['过', 'O']],
#   [['患者：没有，去年冬天有过', 'O'], ['肺炎', 'Symptom']],
#   [['医生：根据描述症状考虑宝宝', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['可能性大，建议带宝宝到医院找医生听一下气管，最好做一下', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['和', 'O'],
#    ['CR', 'Medical_Examination'],
#    ['CP', 'Medical_Examination'],
#    ['，分析一下是', 'O'],
#    ['病毒', 'Symptom'],
#    ['病感', 'Symptom'],
#    ['病染', 'Symptom'],
#    ['还是', 'O'],
#    ['细菌', 'Symptom'],
#    ['细感', 'Symptom'],
#    ['细染', 'Symptom'],
#    ['，拍', 'O'],
#    ['胸片', 'Medical_Examination'],
#    ['检查', 'Medical_Examination'],
#    ['，了解一下肺部和气管炎症情况。', 'O']],
#   [['患者：去诊所听没啥事就回家了', 'O']],
#   [['医生：建议到公立医院规范', 'O'], ['检查', 'Medical_Examination']],
#   [['患者：嗯嗯好的', 'O']],
#   [['医生：祝宝宝健康成长', 'O']],
#   [['医生：还有其他问题吗？', 'O']],
#   [['患者：没了谢谢', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：你好，那说明宝宝好起来了呀', 'O']],
#   [['患者：可是拉的也太多了吧，吃了没多久就拉了，', 'O']],
#   [['患者：会不吸收营养吗', 'O']],
#   [['医生：一天4次，软的不是水样说明有好起来', 'O']],
#   [['医生：', 'O'], ['拉肚', 'Symptom'], ['拉子', 'Symptom'], ['确实会影响营养吸收', 'O']],
#   [['患者：之前是', 'O'],
#    ['水样', 'Symptom'],
#    ['，这两天给她吃了', 'O'],
#    ['蒙脱', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['，就拉软的', 'O']],
#   [['医生：恩，宝宝现在吃的是母乳吗', 'O']],
#   [['患者：是的', 'O']],
#   [['患者：之前', 'O'], ['拉水', 'Symptom'], ['的时候一天一般是两次', 'O']],
#   [['医生：一天4次的大便不算次数很多', 'O']],
#   [['医生：疾病恢复有个过程，要慢慢好起来', 'O']],
#   [['医生：现在没有添加辅食吧？', 'O']],
#   [['患者：那还要吃药吗', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：恩，', 'O'], ['拉肚', 'Symptom'], ['拉子', 'Symptom'], ['不要吃', 'O']],
#   [['医生：有吃', 'O'],
#    ['益生', 'Drug_Category'],
#    ['益菌', 'Drug_Category'],
#    ['吗？', 'O']],
#   [['医生：小便跟平常差不多吗？', 'O']],
#   [['患者：有，没吃，一样', 'O']],
#   [['医生：可以给宝宝吃', 'O'], ['益生', 'Drug_Category'], ['益菌', 'Drug_Category']],
#   [['患者：吃了没用', 'O']],
#   [['医生：这个不会立竿见影，是属于调理的', 'O']],
#   [['患者：拉水拉了有20天，吃了药，开始就是吃', 'O'],
#    ['益生', 'Drug_Category'],
#    ['益菌', 'Drug_Category'],
#    ['没用', 'O']],
#   [['患者：我担心药吃多了不好，前两天', 'O'], ['感冒', 'Symptom'], ['也吃了药', 'O']],
#   [['患者：现在早上起床总是会', 'O'], ['几声', 'O']],
#   [['医生：', 'O'],
#    ['蒙托', 'Drug'],
#    ['蒙石', 'Drug'],
#    ['蒙散', 'Drug'],
#    ['的话如果水分还是有点多那就继续吃', 'O']],
#   [['医生：看大便水分情况', 'O']],
#   [['患者：有一次有一点点水，其她没有', 'O']],
#   [['医生：那可以不吃了', 'O']],
#   [['患者：哦哦', 'O']],
#   [['患者：宝宝吃冰糖雪梨水可以吗', 'O']],
#   [['患者：有点', 'O'], ['咳嗽', 'Symptom']],
#   [['医生：', 'O'], ['拉肚', 'Symptom'], ['拉子', 'Symptom'], ['没完全好不建议吃', 'O']],
#   [['患者：今天吃了两次，有影响吗', 'O']],
#   [['医生：会有影响的', 'O']],
#   [['患者：哦哦，那', 'O'], ['咳嗽', 'Symptom'], ['怎么办', 'O']],
#   [['医生：', 'O'], ['糖浆', 'Drug_Category'], ['可以吃一点', 'O']],
#   [['患者：那是药吗', 'O']],
#   [['医生：恩', 'O']],
#   [['医生：', 'O'], ['止咳', 'Drug'], ['止糖', 'Drug'], ['止浆', 'Drug']],
#   [['患者：那有副作用吗', 'O']],
#   [['医生：比较小的', 'O']],
#   [['医生：选择1岁以内儿童可以吃的', 'O']],
#   [['患者：好的，谢谢', 'O']],
#   [['医生：还有其他问题吗', 'O']],
#   [['医生：您有任何问题可以随时和我联系或留言，我看到后会第一时间回复。', 'O']],
#   [['医生：您好，现在主要症状是什么？', 'O']],
#   [['患者：', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['，', 'O'],
#    ['咳嗽', 'Symptom']],
#   [['医生：孩子还在', 'O'], ['发烧', 'Symptom'], ['不？', 'O']],
#   [['患者：不停的', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'], ['的出来', 'O'], ['没有', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['几天了', 'O']],
#   [['医生：', 'O'], ['咳嗽', 'Symptom'], ['频率较前有加重没有', 'O']],
#   [['患者：昨天一点点，严重了', 'O']],
#   [['医生：您们宝宝，有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['，', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['的症状，这种属于', 'O'],
#    ['呼吸', 'Symptom'],
#    ['呼道', 'Symptom'],
#    ['呼感', 'Symptom'],
#    ['呼染', 'Symptom'],
#    ['的表现', 'O']],
#   [['医生：可能是', 'O'], ['支气', 'Symptom'], ['支管', 'Symptom'], ['支炎', 'Symptom']],
#   [['患者：用什么药好些？', 'O']],
#   [['医生：', 'O'],
#    ['发烧', 'Symptom'],
#    ['的时候', 'O'],
#    ['化验', 'Medical_Examination'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['没有', 'O']],
#   [['患者：没有', 'O']],
#   [['医生：多长时间没有', 'O'], ['发烧', 'Symptom'], ['了', 'O']],
#   [['患者：如果有', 'O'], ['发烧', 'Symptom'], ['可能是什么病症？', 'O']],
#   [['医生：还是支持', 'O'], ['支气', 'Symptom'], ['支管', 'Symptom'], ['支炎', 'Symptom']],
#   [['患者：今天', 'O']],
#   [['医生：这种情况', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['比较严重，我还是建议去找医生', 'O'],
#    ['听诊', 'Medical_Examination'],
#    ['一下肺部', 'O']],
#   [['患者：哦', 'O']],
#   [['医生：然后根据肺部情况觉定是否照片还是口服药物和', 'O'], ['雾化', 'Operation'], ['止咳治疗', 'O']],
#   [['患者：要是', 'O'],
#    ['支气', 'Symptom'],
#    ['支管', 'Symptom'],
#    ['支炎', 'Symptom'],
#    ['用什么药好？', 'O']],
#   [['医生：我们不针对个人提供处方药物，因为网络局限性', 'O']],
#   [['医生：针对', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['可以选择', 'O'],
#    ['止咳', 'Drug_Category'],
#    ['止化', 'Drug_Category'],
#    ['止痰', 'Drug_Category'],
#    ['止药', 'Drug_Category'],
#    ['止物', 'Drug_Category'],
#    ['，', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['频繁可以选择', 'O'],
#    ['雾化', 'Operation'],
#    ['治疗', 'O']],
#   [['患者：好的，谢谢', 'O']],
#   [['医生：同时如果有', 'O'],
#    ['发烧', 'Symptom'],
#    ['，还要', 'O'],
#    ['血常', 'Medical_Examination'],
#    ['血规', 'Medical_Examination'],
#    ['看到底是', 'O'],
#    ['病毒', 'Symptom'],
#    ['病感', 'Symptom'],
#    ['病染', 'Symptom'],
#    ['还是', 'O'],
#    ['细菌', 'Symptom'],
#    ['细感', 'Symptom'],
#    ['细染', 'Symptom'],
#    ['导致', 'O']],
#   [['医生：然后根据结果指导用药', 'O']],
#   [['患者：嗯', 'O']],
#   [['医生：请问，您还有什么问题需要咨询？', 'O']],
#   [['患者：没有了，谢谢', 'O']],
#   [['医生：您好，很高兴为您服务，为了更好的提供服务，我需要询问您几个与病症相关的问题，感谢您配合，谢谢您。', 'O']],
#   [['医生：您好，这是腋温吗？', 'O']],
#   [['患者：恩，是的', 'O']],
#   [['医生：孩子有', 'O'],
#    ['咳嗽', 'Symptom'],
#    ['呕吐', 'Symptom'],
#    ['腹泻', 'Symptom'],
#    ['等症状吗？', 'O']],
#   [['患者：暂时没有', 'O']],
#   [['医生：有点', 'O'], ['低热', 'Symptom'], ['，但不高的，您可以先给他物理降温，多饮食，洗个温水澡的哦', 'O']],
#   [['医生：应该是多饮水', 'O']],
#   [['医生：请问孩子的精神反应怎么样呢？', 'O']],
#   [['患者：恩，她今天', 'O'], ['留清', 'Symptom'], ['留鼻', 'Symptom'], ['留涕', 'Symptom']],
#   [['患者：有点', 'O'], ['感冒', 'Symptom'], ['，老说鼻子不舒服', 'O']],
#   [['医生：您可以先给他吃点预防', 'O'],
#    ['上呼', 'Symptom'],
#    ['上吸', 'Symptom'],
#    ['上道', 'Symptom'],
#    ['上感', 'Symptom'],
#    ['上染', 'Symptom'],
#    ['的用药的哦', 'O']],
#   [['患者：精神不是很好', 'O']],
#   [['医生：一般', 'O'],
#    ['低热', 'Symptom'],
#    ['的话，孩子的精神反应会差一些，您在关注体温，如果体温超过', 'O'],
#    ['38', 'Symptom'],
#    ['3度', 'Symptom'],
#    ['35', 'Symptom'],
#    ['，需要用', 'O'],
#    ['退热', 'Drug_Category'],
#    ['退药', 'Drug_Category'],
#    ['的，没有超过', 'O'],
#    ['38', 'Symptom'],
#    ['3度', 'Symptom'],
#    ['，您可以给他洗澡，物理降温的。', 'O']],
#   [['患者：（空）', 'O']],
#   [['医生：孩子还是有感染的，但', 'O'],
#    ['感冒', 'Symptom'],
#    ['初期一般以病毒感染为主，所以您的用药先以', 'O'],
#    ['抗病', 'Drug_Category'],
#    ['抗毒', 'Drug_Category'],
#    ['清热', 'Drug_Category'],
#    ['清解', 'Drug_Category'],
#    ['清毒', 'Drug_Category'],
#    ['类的用药为主的。', 'O']],
#   [['患者：这个可以吗？', 'O']],
#   [['医生：可以的。', 'O']],
#   [['患者：恩，好的，非常感谢', 'O']],
#   [['医生：一定要多喝水哦，如果', 'O'],
#    ['发热', 'Symptom'],
#    ['越来越高，尽量去附近医院就诊一下，明确感染病灶和感染的性质的。', 'O']],
#   [['患者：恩，好的', 'O']],
#   [['医生：好的，不客气的。', 'O']],
#   [['医生：你好', 'O']],
#   [['患者：宝宝', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['，还', 'O'],
#    ['发烧', 'Symptom'],
#    ['怎么办啊', 'O']],
#   [['医生：这孩子现在精神状态怎么样？尿量怎么样', 'O']],
#   [['医生：超过', 'O'],
#    ['38', 'Symptom'],
#    ['3.', 'Symptom'],
#    ['35', 'Symptom'],
#    ['度需要给孩子口服', 'O'],
#    ['退热', 'Drug_Category'],
#    ['退药', 'Drug_Category'],
#    ['退物', 'Drug_Category']],
#   [['患者：', 'O'],
#    ['尿比', 'Symptom'],
#    ['尿平', 'Symptom'],
#    ['尿常', 'Symptom'],
#    ['尿少', 'Symptom']],
#   [['患者：', 'O'],
#    ['退烧', 'Drug_Category'],
#    ['退药', 'Drug_Category'],
#    ['吃了', 'O']],
#   [['医生：这样的孩子需要多喝水的，避免', 'O'], ['脱水', 'Symptom']],
#   [['医生：根据你所描述的情况，这个孩子需要考虑', 'O'],
#    ['病毒', 'Symptom'],
#    ['病性', 'Symptom'],
#    ['病肠', 'Symptom'],
#    ['病炎', 'Symptom'],
#    ['！', 'O']],
#   [['医生：这孩子出现', 'O'],
#    ['发热', 'Symptom'],
#    ['之前有没有受凉的情况，有没有', 'O'],
#    ['呼吸', 'Symptom'],
#    ['呼道', 'Symptom'],
#    ['呼感', 'Symptom'],
#    ['呼染', 'Symptom'],
#    ['的情况？', 'O']],
#   [['患者：孩子还在吃母乳，喝水比较少，一直在吃母乳', 'O']],
#   [['患者：前几天', 'O'],
#    ['感冒', 'Symptom'],
#    ['在医院', 'O'],
#    ['输液', 'Operation'],
#    ['7天', 'O']],
#   [['医生：这样的孩子应该多喝水的，尽可能少吃奶应该以米粉为主，如果就是想吃奶，应该是腹泻奶粉', 'O']],
#   [['医生：是不是在', 'O'],
#    ['感冒', 'Symptom'],
#    ['的后期出现', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['？', 'O']],
#   [['患者：是的', 'O']],
#   [['医生：现在的这种情况需要继续', 'O'],
#    ['输液', 'Operation'],
#    ['治疗的！反复的', 'O'],
#    ['腹泻', 'Symptom'],
#    ['可能会导致孩子出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况', 'O']],
#   [['患者：', 'O'],
#    ['输液', 'Operation'],
#    ['停了一天，然后就', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom'],
#    ['发烧', 'Symptom']],
#   [['医生：这孩子没有', 'O'], ['呕吐', 'Symptom'], ['的情况吧', 'O']],
#   [['患者：昨天有', 'O']],
#   [['患者：今天没有', 'O']],
#   [['患者：她有', 'O'], ['，不吃药一哭就', 'O'], ['了', 'O']],
#   [['医生：那应该问题不大的', 'O']],
#   [['医生：这种情况需要让孩子多喝水的', 'O']],
#   [['患者：今天', 'O'],
#    ['没有了，还是', 'O'],
#    ['流鼻', 'Symptom'],
#    ['流涕', 'Symptom'],
#    ['，', 'O'],
#    ['发烧', 'Symptom'],
#    ['，', 'O'],
#    ['拉肚', 'Symptom'],
#    ['拉子', 'Symptom']],
#   [['医生：可以选择口服', 'O'], ['补液', 'Drug'], ['补盐', 'Drug']],
#   [['医生：如果这个孩子刚开始有', 'O'],
#    ['呼吸', 'Symptom'],
#    ['呼道', 'Symptom'],
#    ['呼感', 'Symptom'],
#    ['呼染', 'Symptom'],
#    ['的情况，出现', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，需要注意', 'O'],
#    ['轮状', 'Symptom'],
#    ['轮病', 'Symptom'],
#    ['轮毒', 'Symptom'],
#    ['轮肠', 'Symptom'],
#    ['轮炎', 'Symptom'],
#    ['的可能', 'O']],
#   [['患者：', 'O'], ['肠炎', 'Symptom'], ['是什么症状呢', 'O']],
#   [['医生：', 'O'],
#    ['轮状', 'Symptom'],
#    ['轮病', 'Symptom'],
#    ['轮毒', 'Symptom'],
#    ['轮肠', 'Symptom'],
#    ['轮炎', 'Symptom'],
#    ['最常见的症状就是', 'O'],
#    ['腹泻', 'Symptom'],
#    ['，', 'O'],
#    ['呕吐', 'Symptom'],
#    ['发热', 'Symptom'],
#    ['，这个大便是', 'O'],
#    ['蛋花', 'Symptom'],
#    ['蛋汤', 'Symptom'],
#    ['蛋样', 'Symptom'],
#    ['蛋大', 'Symptom'],
#    ['蛋便', 'Symptom'],
#    ['，大便当中', 'O'],
#    ['奶瓣', 'Symptom'],
#    ['比较多，水特别的多', 'O']],
#   [['患者：', 'O'],
#    ['输液', 'Operation'],
#    ['的时候没', 'O'],
#    ['，停的那一天也没拉，是停药的第二天拉的', 'O']],
#   [['患者：我家宝宝出了', 'O'], ['呕吐', 'Symptom'], ['别的症状都有', 'O']],
#   [['医生：对呀，它有个潜伏期', 'O']],
#   [['医生：不可能每个孩子所有的症状都出现的', 'O']],
#   [['医生：这个孩子需要到医院进行', 'O'],
#    ['轮状', 'Medical_Examination'],
#    ['轮病', 'Medical_Examination'],
#    ['轮毒', 'Medical_Examination'],
#    ['轮抗', 'Medical_Examination'],
#    ['轮体', 'Medical_Examination'],
#    ['的', 'O'],
#    ['检查', 'Medical_Examination']],
#   [['患者：那必须要', 'O'], ['输液', 'Operation'], ['吗', 'O']],
#   [['患者：', 'O'], ['验血', 'Medical_Examination'], ['吗', 'O']],
#   [['医生：如果这个孩子能够喝口服', 'O'],
#    ['补液', 'Drug'],
#    ['补盐', 'Drug'],
#    ['，尿量正常，可以先口服药物试试看', 'O']],
#   [['医生：', 'O'],
#    ['轮状', 'Medical_Examination'],
#    ['轮病', 'Medical_Examination'],
#    ['轮毒', 'Medical_Examination'],
#    ['轮抗', 'Medical_Examination'],
#    ['轮体', 'Medical_Examination'],
#    ['是', 'O'],
#    ['大便', 'Medical_Examination'],
#    ['的', 'O']],
#   [['患者：', 'O'], ['补液', 'Drug'], ['补盐', 'Drug'], ['是药的名字吗', 'O']],
#   [['医生：是的', 'O']],
#   [['患者：大约几天能够好', 'O']],
#   [['医生：', 'O'],
#    ['轮状', 'Symptom'],
#    ['轮病', 'Symptom'],
#    ['轮毒', 'Symptom'],
#    ['轮肠', 'Symptom'],
#    ['轮炎', 'Symptom'],
#    ['的病程应该在一个周左右', 'O']],
#   [['医生：高峰期为3到4天', 'O']],
#   [['患者：不', 'O'], ['输液', 'Operation'], ['，一周过后会好嘛', 'O']],
#   [['患者：还是会严重', 'O']],
#   [['医生：前提是没有出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['的情况，一定要', 'O'],
#    ['补液', 'Operation'],
#    ['的', 'O']],
#   [['医生：因为', 'O'],
#    ['轮状', 'Symptom'],
#    ['轮病', 'Symptom'],
#    ['轮毒', 'Symptom'],
#    ['轮肠', 'Symptom'],
#    ['轮炎', 'Symptom'],
#    ['很容易出现', 'O'],
#    ['脱水', 'Symptom'],
#    ['，会出现水', 'O'],
#    ['电解', 'Drug_Category'],
#    ['电质', 'Drug_Category'],
#    ['的紊乱', 'O']],
#   [['医生：如果这个孩子出现', 'O'],
#    ['精神', 'Symptom'],
#    ['精状', 'Symptom'],
#    ['精态', 'Symptom'],
#    ['精差', 'Symptom'],
#    ['，首先需要的就是', 'O'],
#    ['补液', 'Operation'],
#    ['，补足液体以后精神状态仍然不佳，需要进行', 'O'],
#    ['心电', 'Medical_Examination'],
#    ['心图', 'Medical_Examination'],
#    ['的', 'O'],
#    ['检查', 'Medical_Examination'],
#    ['，以排除心肌损伤', 'O']],
#   [['患者：什么情况是孩子', 'O'], ['脱水', 'Symptom'], ['呢', 'O']],
#   [['医生：首先的表现就是', 'O'],
#    ['尿量', 'Symptom'],
#    ['尿减', 'Symptom'],
#    ['尿少', 'Symptom']],
#   [['患者：现在吃点什么药可以缓解一下呢', 'O']],
#   [['医生：口服', 'O'], ['思密', 'Drug'], ['思达', 'Drug'], ['胃肠黏膜', 'O']],
#   [['医生：最主要的就是多喝水', 'O']],
#   [['患者：大约一天喝多少', 'O']],
#   [['医生：这孩子体重是多少', 'O']],
#   [['患者：20斤', 'O']],
#   [['医生：每天至少喝七百毫升水', 'O']],
#   [['医生：这只是额外补充的水量', 'O']],
#   [['患者：出了', 'O'], ['补液', 'Drug'], ['补盐', 'Drug'], ['可以吃别的嘛', 'O']],
#   [['医生：', 'O'], ['思密', 'Drug'], ['思达', 'Drug']],
#   [['患者：', 'O'],
#    ['思密', 'Drug'],
#    ['思达', 'Drug'],
#    ['和', 'O'],
#    ['补液', 'Drug'],
#    ['补盐', 'Drug'],
#    ['吃一个就可以吗', 'O']],
#   [['医生：这两个都需要吃的', 'O']],
#   [['医生：口服', 'O'],
#    ['补液', 'Drug'],
#    ['补盐', 'Drug'],
#    ['是补充液体，', 'O'],
#    ['思密', 'Drug'],
#    ['思达', 'Drug'],
#    ['是保护胃肠黏膜的', 'O']],
#   [['患者：吃到不拉为止吗', 'O']],
#   [['医生：', 'O'], ['思密', 'Drug'], ['思达', 'Drug'], ['最少吃3到4天', 'O']],
#   [['患者：几个小时吃一次', 'O']],
#   [['医生：孩子', 'O'],
#    ['腹泻', 'Symptom'],
#    ['的症状明显的缓解，尿量正常，可以不喝口服', 'O'],
#    ['补液', 'Drug'],
#    ['补盐', 'Drug']],
#   [['患者：', 'O'], ['补液', 'Drug'], ['补盐', 'Drug'], ['一次吃多少', 'O']],
#   [['医生：', 'O'], ['思密', 'Drug'], ['思达', 'Drug'], ['每次半包，一天三次', 'O']],
# ...
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'I-Symptom', 'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'I-Symptom', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom'],
#   ['O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'B-Symptom', 'I-Symptom', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Symptom',
#    'I-Symptom',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'O',
#    'B-Drug',
#    'I-Drug',
#    'I-Drug',
#    'I-Drug'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O',
#    'O',
#    'O',
#    'B-Drug_Category',
#    'I-Drug_Category',
#    'I-Drug_Category',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Drug_Category',
#    'I-Drug_Category',
#    'I-Drug_Category'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'B-Medical_Examination',
#    'I-Medical_Examination',
#    'O',
#    'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O'],
#   ['O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'O',
#    'B-Medical_Examination',
#    'I-Medical_Examination'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O'],
#   ['O', 'O', 'O', 'O', 'O'],
#   ...])

# %%
if __name__ == '__main__':
    data_path = './ner_data/ccks.txt'
    d1 = load_data(data_path,128)

# %%
d1[-1][0]
# Out:
# ['B-prov',
#  'I-prov',
#  'I-prov',
#  'B-city',
#  'I-city',
#  'I-city',
#  'B-district',
#  'I-district',
#  'I-district',
#  'B-town',
#  'I-town',
#  'I-town',
#  'I-town',
#  'B-road',
#  'I-road',
#  'I-road',
#  'B-roadno',
#  'I-roadno',
#  'B-poi',
#  'I-poi',
#  'I-poi',
#  'I-poi',
#  'B-roomno',
#  'I-roomno']
